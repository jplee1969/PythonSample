# %% [markdown]
# # 第九章 网站信息爬取

# %% [markdown]
# - Python 语言发展中有一个里程碑式的应用事件，即美国谷歌（GOOGLE）公司在搜索引擎后端采用Python 语言进行链接处理和开发，这是该语言发展成熟的重要标志。Python 语言的简洁性和脚本特点非常适合链接和网页处理。
# - 万维网（WWW）的快速发展带来了大量获取和提交网络信息的需求，这产生了“网络爬虫”等一系列应用。
# - Python 语言提供了很多类似的函数库，包括urllib、urllib2、urllib3、wget、scrapy、<span class="burk">requests</span> 等。这些库作用不同、使用方式不同、用户体验不同。
# - 对于爬取回来的网页内容，可以通过<span class="burk">re（正则表达式）</span>、<span class="burk">beautifulsoup</span>4等函数库来处理，随着该领域各函数库的发展，本章将详细介绍其中最重要且最主流的两个函数库：<span class="burk">requests 和beautifulsoup4</span>，它们都是第三方库。
# - 网络爬虫应用一般分为两个步骤：（1）<span class="girk">通过网络连接获取网页内容</span>（2）<span class="girk">对获得的网页内容进行处理</span>。
# - 这两个步骤分别使用不同的函数库：requests 和beautifulsoup4

# %% [markdown]
# ## 数据来源
# - 交易数据
# - 移动通讯数据
# - 机器和传感器数据
# - <span class="burk">互联网上的“开放数据”</span>

# %% [markdown]
# ## 预备知识-浏览网页的基本过程和爬虫的基本工作原理
# ### 浏览网页的过程
# - 输入网址
# - 通过DNS服务器解析域名，找到服务器对应的IP地址
# - 向服务器发送URL请求
# - 服务器相应请求，发送HTML到客户端
# - 客户端浏览器解析HTML，显示结果
#
# ### 爬虫的基本工作原理
# - <span class="burk">获取网页HTML</span>
# - <span class="burk">解析HTML，提取所需的数据</span>
# - 数据预处理
# - 数据存储
# - 数据分析
#
# ### 网页爬虫
# - 使用Python 语言实现网络爬虫和信息提交是非常简单的事情，代码行数很少，也无须知道网络通信等方面知识，非常适合非专业读者使用。然而，肆意的爬取网络数据并不是文明现象，通过程序自动提交内容争取竞争性资源也不公平。就像那些肆意的推销电话一样，他们无视接听者意愿，不仅令人讨厌也有可能引发法律纠纷。
# - 拓展：Robots 排除协议
#
# ### 安装相关库
# - pip install <span class="burk">requests</span>
# - pip install <span class="burk">beautifulsoup4</span>

# %% [markdown]
# ### requests库的使用
# - requests 库是一个简洁且简单的处理HTTP请求的第三方库。
# - requests的最大优点是程序编写过程更接近正常URL 访问过程。
# - request 库支持非常丰富的链接访问功能，包括：国际域名和URL 获取、HTTP 长连接和连接缓存、HTTP 会话和Cookie 保持、浏览器使用风格的SSL 验证、基本的摘要认证、有效的键值对Cookie 记录、自动解压缩、自动内容解码、文件分块上传、HTTP(S)代理功能、连接超时处理、流数据下载等。
# - requests 库中的网页请求函数get()是获取网页最常用的方式，在调用requests.get()函数后，返回的网页内容会保存为一个Response 对象，其中，get()函数的参数url 必须链接采用HTTP 或HTTPS方式访问。
# - 通过Response 对象的属性获取网页内容。text 属性是请求的页面内容，以字符串形式展示。
# - encoding 属性非常重要，它给出了返回页面内容的编码方式，可以通过对encoding 属性赋值更改编码方式，以便于处理中文字符。
# - Response对象的raise_for_status()方法能在非成功响应后产生异常，即只要返回的请求状态status_code 不是200，这个方法会产生一个异常，用于try…except 语句。

# %%
# requests的get使用举例，获取学校首页
import requests
url = "https://www.szpt.edu.cn"
r = requests.get(url)
r.encoding = r.apparent_encoding
#print(r.status_code)
#print(r.text)
# Out:
# <!DOCTYPE html><html lang="en"><head><title>深圳职业技术学院</title><META Name="keywords" Content="深圳职业技术学院" />
#
#
#
#
#
# <meta charset="UTF-8">
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <meta name="360-site-verification" content="e568f20d9eccbbe26677079e6ca45884">
# <meta name="viewport" content="width=device-width, initial-scale=1"><link rel="stylesheet" href="css/bootstrap.min.css"><link rel="stylesheet" type="text/css" href="css/style.css" media="screen"><script src="js/jquerya.js"></script><script src="js/jquery.js" type="text/javascript"></script><script type="text/javascript" src="js/SuperSlide.js"></script><script type="text/javascript" src="js/jquery.niceHover.js"></script>
#
# <!--Announced by Visual SiteBuilder 9-->
# <link rel="stylesheet" type="text/css" href="_sitegray/_sitegray_d.css" />
# <script language="javascript" src="_sitegray/_sitegray.js"></script>
# <!-- CustomerNO:77656262657232307c78475d50525742000000004457 -->
# <link rel="stylesheet" type="text/css" href="index.vsb.css" />
# <script type="text/javascript" src="/system/resource/js/vsbscreen.min.js" id="_vsbscreen" devices="pc|pad"></script>
# <script type="text/javascript" src="/system/resource/js/counter.js"></script>
# <script type="text/javascript">_jsq_(1001,'/index.jsp',-1,1409161160)</script>
# </head>
# <body>
# <div class="top">
# <div class="con clearfix">
# <div class="fangke fl">
# <ul class="clearfix"><script language="javascript" src="/system/resource/js/dynclicks.js"></script><script language="javascript" src="/system/resource/js/openlink.js"></script><li class="bg_01"><a href="http://english.szpt.edu.cn/" title="" onclick="_addDynClicks(&#34;wburl&#34;, 1409161160, 37988)">English</a></li>
# <li class="bg_02"><a href="fwjs/xs.htm" title="" onclick="_addDynClicks(&#34;wburl&#34;, 1409161160, 37989)">学生</a></li>
# <li class="bg_03"><a href="fwjs/jg.htm" title="" onclick="_addDynClicks(&#34;wburl&#34;, 1409161160, 37990)">教工</a></li>
# <li class="bg_04"><a href="fwjs/fk.htm" title="" onclick="_addDynClicks(&#34;wburl&#34;, 1409161160, 37991)">访客</a></li>
#
# 		<li class="bg_05"><a href="javascript:void(0);" title="手机版" onclick="_vsb_multiscreen.setDevice('mobile')">手机版</a><li>
# </ul></div>
# <div class="top_link fl">
# <ul class="clearfix">    <LI><a href="http://email.szpt.edu.cn" target="_blank" title="" onclick="_addDynClicks(&#34;wburl&#34;, 1409161160, 37992)">教师邮箱</a></li>
#     <LI><a href="http://mail.mail.szpt.edu.cn/" target="_blank" title="" onclick="_addDynClicks(&#34;wburl&#34;, 1409161160, 37993)">学生邮箱</a></li>
# <script type="text/javascript">
#     function _nl_ys_check(){
#
#         var keyword = document.getElementById('showkeycode199353').value;
#         if(keyword==null||keyword==""){
#             alert("请输入你要检索的内容！");
#             return false;
#         }
#         if(window.toFF==1)
#         {
#             document.getElementById("lucenenewssearchkey199353").value = Simplized(keyword );
#         }else
#         {
#             document.getElementById("lucenenewssearchkey199353").value = keyword;
#         }
#         var  base64 = new Base64();
#         document.getElementById("lucenenewssearchkey199353").value = base64.encode(document.getElementById("lucenenewssearchkey199353").value);
#         new VsbFormFunc().disableAutoEnable(document.getElementById("showkeycode199353"));
#         return true;
#     }
# </script>
# <li style="display:none">
# 	<a href="javascript:void(0)" class="search_but" onclick="searchClick()"><img src="images/search_icon.png" /></a>
# 	<form action="search_close.jsp?wbtreeid=1001" method="post" id="au3a" name="au3a" onsubmit="return _nl_ys_check()" style="display: inline">
#  <input type="hidden" id="lucenenewssearchkey199353" name="lucenenewssearchkey" value=""><input type="hidden" id="_lucenesearchtype199353" name="_lucenesearchtype" value="1"><input type="hidden" id="searchScope199353" name="searchScope" value="1">
# 	<span class="search" id="search">
#
# 		<input name="showkeycode" id="showkeycode199353" type="text" class="text" value="请输入关键字" onfocus="if (value =='请输入关键字'){value =''}" onblur="if (value ==''){value='请输入关键字'}" />
# 		<input type="submit" class="sub" value="搜 索" />
# 	</span>
# 	</form>
# </li>
# <li>
# 	<a href="index/wzdt.htm"><img src="images/header_icon_map.png" /></a>
# </li><script language="javascript" src="/system/resource/js/base64.js"></script><script language="javascript" src="/system/resource/js/formfunc.js"></script>
# </ul></div></div></div>
# <div class="head">
# <div class="con2 clearfix">
# <div class="logo fl">
# <!-- 网站logo图片地址请在本组件"内容配置-网站logo"处填写 -->
# <a href="index.htm" title="深圳职业技术学院"><img src="images/logo.png" /></a></div>
# <div class="menu fr"><div class="navigation-up">
#     <div class="navigation-inner">
#         <div class="navigation-v3">
#             <ul>
#                                 <li _t_nav="dh1">
#                     <h2> <a href="xxgk/xxjj.htm" title="学校概况">学校概况</a> </h2>
#                 </li>
#                 <li _t_nav="dh2">
#                     <h2> <a href="szxw.htm" title="深职新闻">深职新闻</a> </h2>
#                 </li>
#                 <li _t_nav="dh3">
#                     <h2> <a href="xysz1.htm" title="学院设置">学院设置</a> </h2>
#                 </li>
#                 <li _t_nav="dh4">
#                     <h2> <a href="jyjx.htm" title="教育教学">教育教学</a> </h2>
#                 </li>
#                 <li _t_nav="dh5">
#                     <h2> <a href="kxyj.htm" title="科学研究">科学研究</a> </h2>
#                 </li>
#                 <li _t_nav="dh6">
#                     <h2> <a href="zsjy1.htm" title="招生就业">招生就业</a> </h2>
#                 </li>
#                 <li _t_nav="dh7">
#                     <h2> <a href="gjjl.htm" title="国际交流">国际交流</a> </h2>
#                 </li>
#                 <li _t_nav="dh8">
#                     <h2> <a href="http://www.lib.szpt.edu.cn" target="_blank" title="图书馆">图书馆</a> </h2>
#                 </li>
#                 <li _t_nav="dh9">
#                     <h2> <a href="xysh1.htm" title="校园生活">校园生活</a> </h2>
#                 </li>
#             </ul>
#         </div>
#     </div>
# </div>
# <div class="navigation-down">
#     <div id="dh1" class="nav-down-menu menu-1" _t_nav="dh1" style="display: none">
#         <div class="navigation-down-inner">
#             <dl class="zst">
#                 <img src="images/pic_5.jpg" width="280" height="120" />
#             </dl>
#             <dl class="nav_3 clearfix">
#                 <dd>
#                     <a href="xxgk/xxjj.htm" title="学校简介">学校简介</a>
#                 </dd>
#                 <dd>
#                     <a href="xxgk/xhxx.htm" title="校徽校训">校徽校训</a>
#                 </dd>
#                 <dd>
#                     <a href="xxgk/xrld.htm" title="现任领导">现任领导</a>
#                 </dd>
#                 <dd>
#                     <a href="xxgk/zzjg.htm" title="组织机构">组织机构</a>
#                 </dd>
#                 <dd>
#                     <a href="xxgk/sssz.htm" title="数说深职">数说深职</a>
#                 </dd>
#                 <dd>
#                     <a href="xxgk/ghbj.htm" title="规划布局">规划布局</a>
#                 </dd>
#                 <dd>
#                     <a href="xxgk1/jbxx.htm" title="信息公开">信息公开</a>
#                 </dd>
#                 <dd>
#                     <a href="xxgk/fzlc.htm" title="发展历程">发展历程</a>
#                 </dd>
#                 <dd>
#                     <a href="xxgk/lrld.htm" title="历任领导">历任领导</a>
#                 </dd>
#                 <dd>
#                     <a href="xxgk/lshm.htm" title="历史回眸">历史回眸</a>
#                 </dd>
#                 <dd>
#                     <a href="xxgk/ldgh.htm" title="领导关怀">领导关怀</a>
#                 </dd>
#                 <dd>
#                     <a href="xxgk/xyfg.htm" title="校园风光">校园风光</a>
#                 </dd>
#                 <dd>
#                     <a href="xxgk/jtyd.htm" title="交通引导">交通引导</a>
#                 </dd>
#             </dl>
#             <dl class="zhaiyao" style="width:450px">
#                 <p>深圳职业技术学院创建于1993年，是国内最早独立举办高等职业技术教育的院校之一，建校以来，学校始终秉承特区“敢为天下先”的改革创新精神，开拓进取，创造了中国高职教育的多个第一。从首届59名学生到如今2万余名在校生，从最初的借用校舍到拥有环境优美、设施优良的五大校区，从默默无闻到蜚声八方，学校闯出了一条中国特色高等职业教育发展之路，被誉为中国高职教育的“一面旗帜”。</p>
#             </dl>
#         </div>
#     </div>
#     <div id="dh2" class="nav-down-menu menu-1" _t_nav="dh2" style="display: none">
#         <div class="navigation-down-inner">
#             <dl class="zst">
#                 <img src="images/pic_55.jpg" width="280" height="120" />
#             </dl>
#             <dl class="nav_2 clearfix">
#                 <dd style="width:100%">
#                     <a href="szxw/bwcxnjsm.htm" title="“不忘初心、牢记使命”主题教育专题 ">“不忘初心、牢记使命”主题教育专题 </a>
#                 </dd>
#                 <dd>
#                     <a href="szxw/txky_szzxd.htm" title="同心抗疫 深职在行动">同心抗疫 深职在行动</a>
#                 </dd>
#                 <dd>
#                     <a href="szxw/szyw.htm" title="深职要闻">深职要闻</a>
#                 </dd>
#                 <dd>
#                     <a href="szxw/mtksz.htm" title="媒体看深职">媒体看深职</a>
#                 </dd>
#                 <dd>
#                     <a href="szxw/sptd.htm" title="视频天地">视频天地</a>
#                 </dd>
#                 <dd>
#                     <a href="http://szytx.szpt.edu.cn/" target="_blank" title="深职院通讯">深职院通讯</a>
#                 </dd>
#                 <dd>
#                     <a href="szxw/szxs.htm" title="深职撷声">深职撷声</a>
#                 </dd>
#                 <dd>
#                     <a href="szxw/xhdz.htm" title="心海荡舟">心海荡舟</a>
#                 </dd>
#             </dl>
#             <dl class="zhaiyao">
#                 <p><span class="nav-ewm">
# <img src="images/szpt-weixin.png">
# 官方微博
# </span>
# <span class="nav-ewm">
# <img src="images/szpt-weibo.png">
# 官方微信
# </span>
# </p>
#             </dl>
#         </div>
#     </div>
#     <div id="dh3" class="nav-down-menu menu-1" _t_nav="dh3" style="display: none">
#         <div class="navigation-down-inner">
#             <dl class="zst">
#                 <img src="images/pic_57.jpg" width="280" height="120" />
#             </dl>
#             <dl class="nav_3 clearfix">
#                 <dd>
#                     <a href="xysz1/lxdxq.htm" title="留仙洞校区">留仙洞校区</a>
#                 </dd>
#                 <dd>
#                     <a href="xysz1/xlhxq.htm" title="西丽湖校区">西丽湖校区</a>
#                 </dd>
#                 <dd>
#                     <a href="xysz1/glsxq.htm" title="官龙山校区">官龙山校区</a>
#                 </dd>
#                 <dd>
#                     <a href="xysz1/hqcxq.htm" title="华侨城校区">华侨城校区</a>
#                 </dd>
#                 <dd>
#                     <a href="xysz1/fhsxq.htm" title="凤凰山校区">凤凰山校区</a>
#                 </dd>
#             </dl>
#             <dl class="zhaiyao" style="width:450px">
#                 <p>学校积极适应深圳及珠三角地区经济社会和产业发展，坚持产教融合，专业设置紧贴深圳“十大重大科技产业”等战略性新兴产业、先进制造业和现代服务业等重点发展领域；形成了专业设置动态机制和预警机制。目前学院共设置16个二级学院，专业77个，覆盖17个专业大类。</p>
#             </dl>
#         </div>
#     </div>
#     <div id="dh4" class="nav-down-menu menu-1" _t_nav="dh4" style="display: none">
#         <div class="navigation-down-inner">
#             <dl class="zst">
#                 <img src="images/pic_5jyjx.jpg" width="280" height="120" />
#             </dl>
#             <dl class="nav_3 clearfix">
#                 <dd>
#                     <a href="jyjx/rcpy1.htm" title="人才培养">人才培养</a>
#                 </dd>
#                 <dd>
#                     <a href="http://jpkc.szpt.edu.cn/rcpy/2016/" target="_blank" title="质量年报">质量年报</a>
#                 </dd>
#                 <dd>
#                     <a href="jyjx/szdw.htm" title="师资队伍">师资队伍</a>
#                 </dd>
#                 <dd>
#                     <a href="jyjx/rczp.htm" title="人才招聘">人才招聘</a>
#                 </dd>
#                 <dd>
#                     <a href="jyjx/zysz.htm" title="专业设置">专业设置</a>
#                 </dd>
#                 <dd>
#                     <a href="jyjx/scjy.htm" title="双创教育">双创教育</a>
#                 </dd>
#                 <dd>
#                     <a href="http://jpkc.szpt.edu.cn/major.aspx" title="重点专业建设">重点专业建设</a>
#                 </dd>
#                 <dd>
#                     <a href="jyjx/kcjs1.htm" title="课程建设">课程建设</a>
#                 </dd>
#                 <dd>
#                     <a href="jyjx/jxzy.htm" title="教学资源">教学资源</a>
#                 </dd>
#                 <dd>
#                     <a href="http://whyr.szpt.edu.cn" target="_blank" title="文化育人">文化育人</a>
#                 </dd>
#                 <dd>
#                     <a href="http://lhdjt.szpt.edu.cn" target="_blank" title="丽湖大讲堂">丽湖大讲堂</a>
#                 </dd>
#             </dl>
#             <dl class="zhaiyao" style="width:450px">
#                 <p>建校以来，深职院的教育教学改革经历了一个从探索起步到逐渐深化发展的过程，人才培养模式日臻完善，专业与课程改革更加深入，教育教学方法不断创新。进入“十三五”以来，深职院以建设世界一流职业院校为目标，全面深化教育教学改革，实施以学生学习成效为导向的OBE人才培养模式改革，深入推进“六个融合”，人才培养模式日臻完善，专业与课程改革更加深入，教育教学方法不断创新。</p>
#             </dl>
#         </div>
#     </div>
#     <div id="dh5" class="nav-down-menu menu-1" _t_nav="dh5" style="display: none">
#         <div class="navigation-down-inner">
#             <dl class="zst">
#                 <img src="images/navpic_6.jpg" width="280" height="120" />
#             </dl>
#             <dl class="nav_2 clearfix">
#                 <dd>
#                     <a href="kxyj/kygk.htm" title="科研概况">科研概况</a>
#                 </dd>
#                 <dd>
#                     <a href="kxyj/yyyf.htm" title="应用研发">应用研发</a>
#                 </dd>
#                 <dd>
#                     <a href="kxyj/cxyy.htm" title="产学研用">产学研用</a>
#                 </dd>
#                 <dd>
#                     <a href="kxyj/pttd.htm" title="平台团队">平台团队</a>
#                 </dd>
#                 <dd>
#                     <a href="kxyj/kyptzs.htm" title="科研平台展示">科研平台展示</a>
#                 </dd>
#                 <dd>
#                     <a href="http://www.lib.szpt.edu.cn/xzfc/" target="_blank" title="深职学者">深职学者</a>
#                 </dd>
#                 <dd>
#                     <a href="http://zjs.szpt.edu.cn" target="_blank" title="技术与职业教育研究所">技术与职业教育研究所</a>
#                 </dd>
#                 <dd>
#                     <a href="http://xb.szpt.edu.cn" target="_blank" title="深职学报">深职学报</a>
#                 </dd>
#             </dl>
#             <dl class="zhaiyao">
#                 <p>25年间，学校科研从零起步跨越式发展，年度科研经费突破亿元大关，累计科研经费总量达到5.81亿元，省部市区级科研平台达到33个，科研实力在同类院校中遥遥领先。</p>
#             </dl>
#         </div>
#     </div>
#     <div id="dh6" class="nav-down-menu menu-1" _t_nav="dh6" style="display: none">
#         <div class="navigation-down-inner">
#             <dl class="zst">
#                 <img src="images/pic_54.jpg" width="280" height="120" />
#             </dl>
#             <dl class="nav_3 clearfix">
#                 <dd class="zsjy-nav" style="width:100%">
#                     <a href="javascript:;" title="学历教育" style="color:#222">学历教育：</a>
# <a href="https://zhaosheng.szpt.edu.cn/" target="_blank" title="高考招生">高考招生</a>
# <a href="https://zhaosheng.szpt.edu.cn/info/1061/1931.htm" target="_blank" title="自主招生">自主招生</a>
#                 </dd>
#                 <dd class="zsjy-nav" style="width:100%">
#                     <a href="javascript:;" title="国际教育" style="color:#222">国际教育：</a>
# <a href="http://fao.szpt.edu.cn/cglx/info_30_itemid_132.html" title="出境留学">出境留学</a>
# <a href="zsjy1/gjjy/gatzs.htm" title="港澳台招生">港澳台招生</a>
#                 </dd>
#                 <dd class="zsjy-nav" style="width:100%">
#                     <a href="javascript:;" title="成人教育" style="color:#222">成人教育：</a>
# <a href="http://jpxy.szpt.edu.cn" title="专升本">专升本</a>
# <a href="http://jpxy.szpt.edu.cn" title="业余大专">业余大专</a>
# <a href="http://jpxy.szpt.edu.cn" title="鉴定与认证">鉴定与认证</a>
#                 </dd>
#                 <dd class="zsjy-nav" style="width:100%">
#                     <a href="javascript:;" title="就业创业" style="color:#222">就业创业：</a>
# <a href="http://jiuye.szpt.edu.cn" target="_blank" title="就业指导">就业指导</a>
# <a href="http://jiuye.szpt.edu.cn/index.php?m=content&c=index&a=lists&catid=7" target="_blank" title="企业招聘信息">企业招聘信息</a>
# <a href="http://cxcy.szpt.edu.cn" title="创新创业">创新创业</a>
#                 </dd>
#             </dl>
#             <dl class="zhaiyao" style="width:450px">
#                 <p>学校紧贴市场办学，每年招生时将依据实际情况对专业进行适当调整，并在部分学院开始试行专业大类、专业群招生，详见深圳职业技术学院招生网站（文字链接地址http://zhaosheng.szpt.edu.cn）</p>
#             </dl>
#         </div>
#     </div>
#     <div id="dh7" class="nav-down-menu menu-1" _t_nav="dh7" style="display: none">
#         <div class="navigation-down-inner">
#             <dl class="zst">
#                 <img src="images/pic_59.jpg" width="280" height="120" />
#             </dl>
#             <dl class="nav_2 clearfix">
#                 <dd>
#                     <a href="gjjl/hzjl.htm" title="合作交流">合作交流</a>
#                 </dd>
#                 <dd>
#                     <a href="gjjl/hzyx.htm" title="合作院校">合作院校</a>
#                 </dd>
#             </dl>
#             <dl class="zhaiyao">
#                 <p>学校紧扣国家发展战略，加快国际化办学步伐，充分利用区域与自身优势，深化国际教育交流与合作。在学生交换、课程合作、科研合作、短期研修等领域与境外合作院校开展了全方位、多层次、形式多样的国际交流合作，为深圳乃至中国职业教育国际交流与发展做出了一定的贡献。</p>
#             </dl>
#         </div>
#     </div>
#     <div id="dh8" class="nav-down-menu menu-1" _t_nav="dh8" style="display: none">
#         <div class="navigation-down-inner">
#             <dl class="zst">
#                 <img src="images/pic_56.jpg" width="280" height="120" />
#             </dl>
#             <dl class="nav_2 clearfix">
#                 <dd>
#                     <a href="tsg/tsggg.htm" title="图书馆公告">图书馆公告</a>
#                 </dd>
#                 <dd>
#                     <a href="http://www.lib.szpt.edu.cn/dzzy/zwzy" title="电子资源">电子资源</a>
#                 </dd>
#                 <dd>
#                     <a href="http://www.lib.szpt.edu.cn/dzfw/zxfw" title="咨询服务">咨询服务</a>
#                 </dd>
#                 <dd>
#                     <a href="http://www.lib.szpt.edu.cn/dzzn/gcfb" title="馆藏服务">馆藏服务</a>
#                 </dd>
#                 <dd>
#                     <a href="http://zygyfw.szpt.edu.cn" title="专业服务网">专业服务网</a>
#                 </dd>
#                 <dd>
#                     <a href="http://www.lib.szpt.edu.cn/reader_club/index.htm" title="读书俱乐部">读书俱乐部</a>
#                 </dd>
#             </dl>
#             <dl class="zhaiyao">
#                 <p>学校图书馆包括留仙洞校区馆、西丽湖校区馆和官龙山校区医学技术分馆。纸质馆藏超过230万册（含中外文图书、期刊），电子图书超过100万册，以及几十种数据库，多媒体资料48000多件，馆内建有先进的书籍采编、收藏、检索、借阅、咨询等系统，建有多间电子阅览室、影视播放室、教师研究室和学习讨论室，并开设了移动图书馆、图书馆微博与微信，加强与读者互动。</p>
#             </dl>
#         </div>
#     </div>
#     <div id="dh9" class="nav-down-menu menu-1" _t_nav="dh9" style="display: none">
#         <div class="navigation-down-inner">
#             <dl class="zst">
#                 <img src="images/nav_xysh.jpg" width="280" height="120" />
#             </dl>
#             <dl class="nav_3 clearfix">
#                 <dd>
#                     <a href="xysh1/xygg.htm" title="校园公告">校园公告</a>
#                 </dd>
#                 <dd>
#                     <a href="xysh1/szxl.htm" title="深职校历">深职校历</a>
#                 </dd>
#                 <dd>
#                     <a href="xysh1/wlfw.htm" title="网络服务">网络服务</a>
#                 </dd>
#                 <dd>
#                     <a href="xysh1/shfw.htm" title="生活服务">生活服务</a>
#                 </dd>
#                 <dd>
#                     <a href="xysh1/xshd.htm" title="学生活动">学生活动</a>
#                 </dd>
#                 <dd>
#                     <a href="xysh1/syjs.htm" title="书院建设">书院建设</a>
#                 </dd>
#                 <dd>
#                     <a href="xysh1/glgd.htm" title="管理规定">管理规定</a>
#                 </dd>
#             </dl>
#             <dl class="zhaiyao" style="width:450px">
#                 <p>学校以高度的文化自觉，强化立德树人的根本任务，实施“文化育人战略”，在国内率先大力倡导和实施文化引领技能人才培养，大力开展文化育人课程建设，开展书院及书香校园建设，创建“志愿者之校”，举办丰富多彩的校园文化及高雅文化育人活动，受到学生喜爱。</p>
#             </dl>
#         </div>
#     </div>
# </div></div></div></div>
# <div id="index"><!-- pc --><div class="banner hidden-xs">
#                 <div class="container">
#                     <div class="calendar-container hidden-xs">
#                         <div class="left fl" style="width:120px;background:#88c0ee">
#                             <div id="calendar_arrow" style="height: 55px;"> </div>
#                         </div>
#                         <ul class="calendar_date" id="calendar_time">
#                         </ul>
#                         <div class="right fr" id="calendar_date">
#                         </div>
#                     </div>
#                 </div>
#                 <div class="carousel" style="height: 420px;position: relative;">
#                     <div class="calendar hidden-xs"> </div>
#                     <div class="sixy1" role="listbox" id="calender_show">
#                         <div name="02" class="newsbox nb_02" style="background: url(images/banner_01.jpg)">
#                             <a href="#" target="_blank"></a>
#                             <div class="container">
#                                 <div class="calendar_tit">
#                                     <h4 class="title fl"> <a href="#">深圳职业技术学院</a> </h4>
#                                 </div>
#                             </div>
#                         </div>
#                     </div>
#                     <a href="javascript:loadPrevious_dy()"> <span id="icon_left"></span> <span class="sr-only">Previous</span> </a>
#                     <a href="javascript:loadNext_dy()"> <span id="icon_right"></span> <span class="sr-only">Next</span> </a>
#                 </div>
#             </div>
# <script type="text/javascript">
#                 //2018/05/22
#                 //author:webber-dy
#                 //version:2.0
#                 var allTargetNews_dy; //存储所有传回数据
#                 var currentIndex_dy; //当前位置
#                 var currentDay_dy; //当前天
#                 var currentMonth_dy; //当前月
#                 var previousMonth_dy; //前一月
#                 var nextMonth_dy; //后一月
#                 var currentMonthStar_dy; //本月开始的index(日期小的，更旧的)
#                 var currentMonthEnd_dy; //本月结束的index(日期大的，更新的)
#                 var locationYear_dy; //当前年
#                 var height_dy = '650px'; //banner区域高度
#                 var width_dy = '100%'; //banner区域宽度
#                 var arrowFace_dy = false; //箭头的朝向，false 向更早加载, true 向更新加载。
#                 var treeid='1311';
#                 var contentid='174198';
#                 var currentDay_dy_1;
#                 /**
#                  * 初始加载函数
#                  */
#                 $(document).ready(function() {
#                     $.post("/system/resource/LoadTargetNews.jsp", {
#                         treeID: treeid,
#                         contentID: contentid
#                     }, function(data) {
#                         if(data == "0") {
#                             alert('暂无内容，请联系管理员');
#                         } else {
#                             allTargetNews_dy = $.parseJSON(data);
#                             currentMonthEnd_dy = -1;
#                             var savf = allTargetNews_dy[0].split('丨');
#                             var ddzz = savf[2].split('-');
#                             if(ddzz[1] != 1) {
#                                 previousMonth_dy = parseInt(ddzz[1]) - 1;
#                             } else {
#                                 previousMonth_dy = 12;
#                             }
#                             if(ddzz[1] != 12) {
#                                 nextMonth_dy = parseInt(ddzz[1]) + 1;
#                             } else {
#                                 nextMonth_dy = 1;
#                             }
#                             document.getElementById("calendar_arrow").innerHTML = '<A href="javascript:loadPreviousMonth_dy();" class="prev"></A>' + parseInt(ddzz[1]) + '月';
#                             locationYear_dy = ddzz[0];
#                             updateBanner_dy(savf, 0, ddzz[2], ddzz[1]);
#                             var days = new Array();
#                             days.push(currentDay_dy);
#                             days = findDaysInMonth_dy(days, ddzz[1], 1, true);
#                             currentMonthStar_dy = days.pop();
#                             updateCanlanderMonth_dy(days, ddzz, ddzz[1], true);
#                             currentDay_dy = ddzz[2];
#                             currentDay_dy_1 = ddzz[2];
#                             currentMonth_dy = ddzz[1];
#                         }
#                     });
#                 });
#                 /** 计算当前月有多少天
#                  *
#                  * @param {Object} year
#                  * @param {Object} month
#                  */
#                 function calcDays_dy(year, month) {
#                     if(month == 1 || month == 3 || month == 5 || month == 7 || month == 8 || month == 10 || month == 12) {
#                         return 31;
#                     }
#                     if(month == 2) {
#                         if(year % 4 == 0 && (year % 100 != 0 || year % 400 == 0)) {
#                             return 29;
#                         } else {
#                             return 28;
#                         }
#                     }
#                     return 30;
#                 }
#                 /**
#                  *  在变换了月份后找出此月内有文章的天数
#                  * @param {Array} days 初始记录
#                  * @param {Object} month
#                  * @param {Object} startIndex 需要查询的月份的开始标记点
#                  * @param {boolean} old boolean true 为更旧的日期， false 为更新的日期
#                  * @return {Array} days 记录天数
#                  */
#                 function findDaysInMonth_dy(days, month, startIndex, old) {
#                     var i;
#                     var savf;
#                     var datess;
#                     if(old) {
#                         for(i = startIndex; i < 32; i++) {
#                             if(i >= allTargetNews_dy.length) {
#                                 break;
#                             }
#                             savf = allTargetNews_dy[i].split('丨');
#                             datess = savf[2].split('-');
#                             if(datess[0] > locationYear_dy) {
#                                 continue;
#                             }
#                             if(datess[0] == locationYear_dy && datess[1] > month) {
#                                 continue;
#                             }
#                             if(datess[0] != locationYear_dy || datess[1] != month) {
#                                 break;
#                             }
#                             days.push(datess[2]);
#                         }
#                         days.push(i);
#                     } else {
#                         for(i = startIndex; i >= 0; i--) {
#                             if(i <= -1) break;
#                             savf = allTargetNews_dy[i].split('丨');
#                             datess = savf[2].split('-');
#                             if(datess[0] < locationYear_dy) {
#                                 continue;
#                             }
#                             if(datess[0] == locationYear_dy && datess[1] < month) {
#                                 continue;
#                             }
#                             if(datess[0] != locationYear_dy || datess[1] != month) {
#                                 break;
#                             }
#                             days.push(datess[2]);
#                         }
#                         days.push(i);
#                     }
#                     if(days.size == 0) {
#                         days.push("no");
#                     }
#                     return days;
#                 }
#                 /**
#                  *  更新日期板
#                  * @param {Object} days
#                  * @param {Object} ddzz
#                  * @param {boolean} order boolean true 为正序， false 为反序
#                  */
#                 function updateCanlanderMonth_dy(days, ddzz, month, order) {
#                     var daysss = calcDays_dy(ddzz[0], ddzz[1]);
#                     var popout = days.pop();
#                     document.getElementById("calendar_time").innerHTML = "";
#                     if(order) {
#                         for(var i = 1; i <= daysss; i++) {
#                             if(popout == i) {
#                                 if(parseInt(ddzz[1]) != parseInt(month) || popout != currentDay_dy_1) {
#                                     document.getElementById("calendar_time").innerHTML += "<li><span class='date_num' id='dayz_dy_" + i + "'><A href='javascript:loadOneDay_dy(" + i + ");'>" + i + "</A></span></li>";
#                                     popout = days.pop();
#                                 } else {
#                                     document.getElementById("calendar_time").innerHTML += "<li><span class='date_num' id='dayz_dy_" + i + "'><b>" + i + "</b></span></li>";
#                                     popout = days.pop();
#                                 }
#                             } else {
#                                 document.getElementById("calendar_time").innerHTML += "<li class='no_news'><span class='date_num'>" + i + "</span></li>";
#                             }
#                         }
#                     } else {
#                         for(var i = daysss; i >= 1; i--) {
#                             if(popout == i) {
#                                 if(parseInt(ddzz[1]) != parseInt(month) || popout != currentDay_dy_1) {
#                                     document.getElementById("calendar_time").innerHTML = "<li><span class='date_num' id='dayz_dy_" + i + "'><A href='javascript:loadOneDay_dy(" + i + ");'>" + i + "</A></span></li>" + document.getElementById("calendar_time").innerHTML;
#                                     popout = days.pop();
#                                 } else {
#                                     document.getElementById("calendar_time").innerHTML = "<li><span class='date_num' id='dayz_dy_" + i + "'><b>" + i + "</b></span></li>" + document.getElementById("calendar_time").innerHTML;
#                                     popout = days.pop();
#                                 }
#                             } else {
#                                 document.getElementById("calendar_time").innerHTML = "<li class='no_news'><span class='date_num'>" + i + "</span></li>" + document.getElementById("calendar_time").innerHTML;
#                             }
#                         }
#                     }
#                 }
#                 /**
#                  * 更新Banner区域
#                  * @param {Object} savf
#                  * @param {Object} index
#                  * @param {Object} dayz
#                  */
#                 function updateBanner_dy(savf, index, dayz, month) {
#                     var urlz = "";
#                     if(savf.length==5){
#                         urlz = savf[4];
#                     }else{
#                         urlz = "/info/"+treeid+"/" + savf[0] + ".htm";
#                     }
#                     var now = new Date();
#                     var m = now.getMonth() + 1;
#                     if(m < 10) {
#                         m = '0' + m;
#                     }
#                     var d = now.getDate();
#                     if(d < 10) {
#                         d = '0' + d;
#                     }
#                     var datess = now.getFullYear() + '-' + m + '-' + d;
#                     if(savf[2] == datess) {
#                         //document.getElementById("calendar_date").innerHTML = "Today";
#                     } else {
#                                                 //document.getElementById("calendar_date").innerHTML = savf[2];
#                     }
#                     var bannerArea = document.getElementById("calender_show");
#                     bannerArea.innerHTML="";
#                     bannerArea.display = "block";
#                     bannerArea.innerHTML= '<div class="newsbox nb_02" style="background-image: url('+savf[3]+'); display:block;"><a href="'+urlz+'" target="_blank"></a><div class="container"><div class="calendar_tit"><h4 class="title fl"> <a href="'+urlz+'" target="_blank">'+savf[1]+'</a> </h4></div></div></div>';
#                     currentIndex_dy = index;
#                     currentDay_dy = dayz;
#                     currentDay_dy_1 = dayz;
#                     currentMonth_dy = month;
#                 }
#                 /**
#                  * 更新日期
#                  * @param {Object} oldDay
#                  * @param {Object} newDay
#                  */
#                 function updateCanlander_dy(oldDay, newDay) {
#                     if(document.getElementById("dayz_dy_" + oldDay) != null) {
#                         document.getElementById("dayz_dy_" + oldDay).innerHTML = "<A href='javascript:loadOneDay_dy(" + oldDay + ");'>" + oldDay + "</A>";
#                     }
#                     document.getElementById("dayz_dy_" + newDay).innerHTML = "<b>" + newDay + "</b>";
#                 }
#                 /**
#                  * 加载前一个 前一个为日期更旧的一个
#                  */
#                 function loadPrevious_dy() {
#                     if(currentIndex_dy == allTargetNews_dy.length - 1) {
#                         return;
#                     }
#                     var index = currentIndex_dy + 1;
#                     var cd = allTargetNews_dy[currentIndex_dy].split('丨')[2].split('-')[2];
#                     var day = allTargetNews_dy[index].split('丨')[2].split('-');
#                     var targetMonth;
#                     while(index < currentMonthEnd_dy) {
#                         loadNextMonth_dy();
#                     }
#                     if(previousMonth_dy == 12) {
#                         targetMonth = 1;
#                     } else {
#                         targetMonth = previousMonth_dy + 1;
#                     }
#                     if(locationYear_dy != day[0] || targetMonth != day[1]) {
#                         while(index == currentMonthEnd_dy) {
#                             loadNextMonth_dy();
#                         }
#                     }
#                     if(index == currentMonthEnd_dy) {
#                         if(previousMonth_dy == 12) {
#                             targetMonth = 1;
#                         } else {
#                             targetMonth = previousMonth_dy + 1;
#                         }
#                         if(targetMonth != day[1]) {
#                             loadNextMonth_dy();
#                         } else {
#                             currentDay_dy = cd;
#                         }
#                     }
#                     while(index > currentMonthStar_dy) {
#                         loadPreviousMonth_dy();
#                     }
#                     if(previousMonth_dy == 12) {
#                         targetMonth = 1;
#                     } else {
#                         targetMonth = previousMonth_dy + 1;
#                     }
#                     if(locationYear_dy != day[0] || targetMonth != day[1]) {
#                         while(index == currentMonthStar_dy) {
#                             loadPreviousMonth_dy();
#                         }
#                     }
#                     if(index == currentMonthStar_dy) {
#                         if(previousMonth_dy == 12) {
#                             targetMonth = 1;
#                         } else {
#                             targetMonth = previousMonth_dy + 1;
#                         }
#                         if(targetMonth != day[1]) {
#                             loadPreviousMonth_dy();
#                         } else {
#                             currentDay_dy = cd;
#                         }
#                     }
#                     loadOneDay_dy(parseInt(day[2]));
#                 }
#                 /**
#                  * 加载下一个 下一个为日期更靠新的一个
#                  */
#                 function loadNext_dy() {
#                     if(currentIndex_dy == 0) {
#                         return;
#                     }
#                     var index = currentIndex_dy - 1;
#                     var day = allTargetNews_dy[index].split('丨')[2].split('-');
#                     var cd = allTargetNews_dy[currentIndex_dy].split('丨')[2].split('-')[2];
#                     var targetMonth;
#                     while(index > currentMonthStar_dy) {
#                         loadPreviousMonth_dy();
#                     }
#                     if(previousMonth_dy == 12) {
#                         targetMonth = 1;
#                     } else {
#                         targetMonth = previousMonth_dy + 1;
#                     }
#                     if(locationYear_dy != day[0] || targetMonth != day[1]) {
#                         while(index == currentMonthStar_dy) {
#                             loadPreviousMonth_dy();
#                         }
#                     }
#                     if(index == currentMonthStar_dy) {
#                         if(targetMonth != day[1]) {
#                             loadPreviousMonth_dy();
#                         } else {
#                             currentDay_dy = cd;
#                         }
#                     }
#                     while(index < currentMonthEnd_dy) {
#                         loadNextMonth_dy();
#                     }
#                     if(previousMonth_dy == 12) {
#                         targetMonth = 1;
#                     } else {
#                         targetMonth = previousMonth_dy + 1;
#                     }
#                     if(locationYear_dy != day[0] || targetMonth != day[1]) {
#                         while(index == currentMonthEnd_dy) {
#                             loadNextMonth_dy();
#                         }
#                     }
#                     if(index == currentMonthEnd_dy) {
#                         if(previousMonth_dy == 12) {
#                             targetMonth = 1;
#                         } else {
#                             targetMonth = previousMonth_dy + 1;
#                         }
#                         if(targetMonth != day[1]) {
#                             loadNextMonth_dy();
#                         } else {
#                             currentDay_dy = cd;
#                         }
#                     }
#                     loadOneDay_dy(parseInt(day[2]));
#                 }
#                 /**
#                  * 加载前一月(只更新日历不更新banner)
#                  */
#                 function loadPreviousMonth_dy() {
#                     var star = currentMonthStar_dy;
#                     if(star == allTargetNews_dy.length) return;
#                     var targetMonth = previousMonth_dy;
#                     if(previousMonth_dy == 1) {
#                         previousMonth_dy = 12;
#                         nextMonth_dy = nextMonth_dy - 1;
#                     } else if(previousMonth_dy == 12) {
#                         locationYear_dy = locationYear_dy - 1;
#                         nextMonth_dy = nextMonth_dy - 1;
#                         previousMonth_dy = previousMonth_dy - 1;
#                     } else if(previousMonth_dy == 11) {
#                         nextMonth_dy = 12;
#                         previousMonth_dy = previousMonth_dy - 1;
#                     } else {
#                         nextMonth_dy = nextMonth_dy - 1;
#                         previousMonth_dy = previousMonth_dy - 1;
#                     }
#                     var ddzz = [locationYear_dy, targetMonth];
#                     var days = new Array();
#                     days = findDaysInMonth_dy(days, targetMonth, star, true);
#                     var d = days.pop();
#                     if(d != null && d != "no") {
#                         currentMonthEnd_dy = currentMonthStar_dy;
#                         currentMonthStar_dy = d;
#                     }
#                     updateCanlanderMonth_dy(days, ddzz, currentMonth_dy, true);
#                     if(currentMonthStar_dy == allTargetNews_dy.length) {
#                         document.getElementById("calendar_arrow").innerHTML = targetMonth + '月' + '<A href="javascript:loadNextMonth_dy();" class="next"></A>';
#                     } else {
#                         document.getElementById("calendar_arrow").innerHTML = '<A href="javascript:loadPreviousMonth_dy();" class="prev"></A>' + targetMonth + '月' + '<A href="javascript:loadNextMonth_dy();" class="next"></A>';
#                     }
#                     currentDay_dy = 32;
#                 }
#                 /**
#                  * 加载后一月 (只更新日历不更新banner)
#                  */
#                 function loadNextMonth_dy() {
#                     var star = currentMonthEnd_dy;
#                     if(star == -1) return;
#                     var targetMonth = nextMonth_dy;
#                     if(nextMonth_dy == 12) {
#                         nextMonth_dy = 1;
#                         previousMonth_dy = previousMonth_dy + 1;
#                     } else if(nextMonth_dy == 2) {
#                         nextMonth_dy = nextMonth_dy + 1;
#                         previousMonth_dy = 1;
#                     } else if(nextMonth_dy == 1) {
#                         locationYear_dy = locationYear_dy + 1;
#                         nextMonth_dy = nextMonth_dy + 1;
#                         previousMonth_dy = previousMonth_dy + 1;
#                     } else {
#                         nextMonth_dy = nextMonth_dy + 1;
#                         previousMonth_dy = previousMonth_dy + 1;
#                     }
#                     var ddzz = [locationYear_dy, targetMonth];
#                     var days = new Array();
#                     days = findDaysInMonth_dy(days, targetMonth, star, false);
#                     var d = days.pop();
#                     if(d != null && d != "no") {
#                         currentMonthStar_dy = star;
#                         currentMonthEnd_dy = d;
#                     }
#                     updateCanlanderMonth_dy(days, ddzz, currentMonth_dy, false);
#                     if(currentMonthEnd_dy == -1) {
#                         document.getElementById("calendar_arrow").innerHTML = '<A href="javascript:loadPreviousMonth_dy();" class="prev"></A>' + targetMonth + '月';
#                     } else {
#                         document.getElementById("calendar_arrow").innerHTML = '<A href="javascript:loadPreviousMonth_dy();" class="prev"></A>' + targetMonth + '月' + '<A href="javascript:loadNextMonth_dy();" class="next"></A>';
#                     }
#                     currentDay_dy = 0;
#                 }
#                 /**
#                  * 根据箭头加载月份
#                  */
#                 function loadMonth_dy(){
#                     if(arrowFace_dy){
#                         if(currentMonthEnd_dy!=-1){
#                             loadNextMonth_dy();
#                         }else{
#                             arrowFace_dy = false;
#                             loadPreviousMonth_dy();
#                         }
#                     }else{
#                         if(currentMonthStar_dy != allTargetNews_dy.length){
#                             loadPreviousMonth_dy();
#                         }else{
#                             arrowFace_dy = true;
#                             loadNextMonth_dy();
#                         }
#                     }
#                 }
#                 /**
#                  * 加载某一天
#                  */
#                 function loadOneDay_dy(day) {
#                     var savf;
#                     var savf2;
#                     var i;
#                     if(day > currentDay_dy) {
#                         for(i = currentIndex_dy - 1; i >= 0; i--) {
#                             if(i > currentMonthStar_dy) continue;
#                             if(i < currentMonthEnd_dy) break;
#                             savf2 = allTargetNews_dy[i].split('丨');
#                             if(savf2[2].split('-')[2] == day) {
#                                 savf = savf2;
#                                 break;
#                             }
#                         }
#                         if(savf == null) {
#                             for(i = currentIndex_dy + 1; i < allTargetNews_dy.length; i++) {
#                                 if(i > currentMonthStar_dy) break;
#                                 if(i < currentMonthEnd_dy) continue;
#                                 savf2 = allTargetNews_dy[i].split('丨');
#                                 if(savf2[2].split('-')[2] == day) {
#                                     savf = savf2;
#                                     break;
#                                 }
#                             }
#                         }
#                         updateCanlander_dy(currentDay_dy_1, day);
#                         updateBanner_dy(savf, i, day, savf[2].split('-')[1]);
#                     } else {
#                         for(var i = currentIndex_dy + 1; i < allTargetNews_dy.length; i++) {
#                             if(i > currentMonthStar_dy) break;
#                             if(i < currentMonthEnd_dy) continue;
#                             savf2 = allTargetNews_dy[i].split('丨');
#                             if(savf2[2].split('-')[2] == day) {
#                                 savf = savf2;
#                                 break;
#                             }
#                         }
#                         if(savf == null) {
#                             for(i = currentIndex_dy - 1; i >= 0; i--) {
#                                 if(i > currentMonthStar_dy) continue;
#                                 if(i < currentMonthEnd_dy) break;
#                                 savf2 = allTargetNews_dy[i].split('丨');
#                                 if(savf2[2].split('-')[2] == day) {
#                                     savf = savf2;
#                                     break;
#                                 }
#                             }
#                         }
#                         updateCanlander_dy(currentDay_dy_1, day);
#                         updateBanner_dy(savf, i, day, savf[2].split('-')[1]);
#                     }
#                 }
#                 </script><!-- graybox --><div class="index-date"><script language="javascript" src="/system/resource/js/calendar/simple.js"></script>
# <script language="JavaScript">
# //阳历
# var c_Calendar199828EnDateString;
#
# var c_Calendar199828WeekDayString;
#
# //阴历
# var c_Calendar199828CnDateString;
# //节气
# var c_Calendar199828JQString;
# //年
# var c_Calendar199828YearString;
# //月
# var c_Calendar199828MonthString;
# //日
# var c_Calendar199828DayString;
# //周
# var c_Calendar199828WeekString;
# function RunGLNL199828()
# {
#     var  sc =new Simple_Calendar ();
#     sc.init();
#     c_Calendar199828CnDateString=sc.getCnDateString();
#     c_Calendar199828WeekDayString=sc.getCalendarWeekString();
#     c_Calendar199828JQString=sc.getJQString();
#     c_Calendar199828EnDateString=sc.getEnDateString();
#     c_Calendar199828YearString=sc.getYearString();
#     c_Calendar199828MonthString=sc.getMonthString();
#     c_Calendar199828DayString=sc.getDayString();
#     c_Calendar199828WeekString=sc.getWeekString();
# }
# RunGLNL199828();
#
# document.write('<div id="c_lunar199828"   >');
# document.write(c_Calendar199828EnDateString);
#
#
#
#
# document.write("</div>");
#
# </script>
# </div></div>
# <div class="clear" style="height: 60px"></div>
# <div class="main con2 index_line clearfix">
# <div class="main_1_left fl">
# <div class="index_title"><span class="more" style="padding-right: 25px"><a href="szxw/szyw.htm"><img src="images/more_jiantou.png"></a></span><i><img src="images/main_icon_1.png"></i>深职要闻 </div>
# <div class="index_box"><script language="javascript" src="/system/resource/js/centerCutImg.js"></script><script language="javascript" src="/system/resource/js/ajax.js"></script><div class="pic">
# 	<ul class="contentbox-six clearfix">
# 							<li class="con-six">
# 						<a href="info/1025/9284.htm" target="_blank" class="img clearfix"><img class="conimg-two" src="/__local/0/9F/46/123CF36C991372CB5359AC3F8DB_62DAA5D3_188B0.jpg" />
# 							<div class="txt-six">
# 								<p>领导嘉宾为“一站式”学生社区党群服务中心揭牌。12月16日，我校在留仙洞校区学生...</p>
# 							</div>
# 						</a>
# 						<a href="info/1025/9284.htm" target="_blank" class="txt" title="我校举行“一站式”学生社区党群服务中心揭牌仪式">我校举行“一站式”学生社区党群服务中心揭牌仪式</a>
# 					</li>
# 					<li class="con-six">
# 						<a href="info/1025/9278.htm" target="_blank" class="img clearfix"><img class="conimg-two" src="/__local/2/24/81/E022006B4499F6E34E1C5AC8A04_5191CB9B_11B2A.jpg" />
# 							<div class="txt-six">
# 								<p>领导嘉宾共同为WFCP教师专业发展委员会揭牌。12月15日，世界职业院校与技术大学联...</p>
# 							</div>
# 						</a>
# 						<a href="info/1025/9278.htm" target="_blank" class="txt" title="世界职业院校与技术大学联盟教师专业发展委员会揭牌仪式在我校举行">世界职业院校与技术大学联盟教师专业发展委员会揭牌仪式在我校举行</a>
# 					</li>
# 	</ul>
# </div><script>_showDynClickBatch(['dynclicks_u8_9284','dynclicks_u8_9278'],[9284,9278],"wbnews", 1409161160)</script>
# <div class="list clearfix">
# 	<ul>
#
# 				<li>
# 					<a href="info/1025/9303.htm" target="_blank" title="学校获评“学习强国”深圳学习平台先进单位荣誉称号">学校获评“学习强国”深圳学习平台先进单位荣誉称号</a>
# ...
# 	<div class="img"><a href="info/1063/9011.htm" target="_blank"><img src="/__local/8/35/3E/BDA84D667C161CEFB85D66ABBFF_0E788922_F1BC.jpg" /></a></div>
# 	<div class="txt">
# 		<a href="info/1063/9011.htm" target="_blank" class="tit" title="我校喜获两项广东省科技进步奖">我校喜获两项广东省科技进步奖</a>
# 	</div>
# </li>
# <li name="other" class="box bg-5 ">
# 	<div class="img"><a href="info/1063/9010.htm" target="_blank"><img src="/__local/C/03/EB/A975223374916029118D24DE0B8_74F5FC63_9413E.jpeg" /></a></div>
# 	<div class="txt">
# 		<a href="info/1063/9010.htm" target="_blank" class="tit" title="我校霍夫曼先进材料研究院再获重要研究进展">我校霍夫曼先进材料研究院再获重要研究进展</a>
# 	</div>
# </li>
# <li name="other" class="box bg-6 nomaright">
# 	<div class="img"><a href="info/1063/9009.htm" target="_blank"><img src="/__local/2/01/C0/23317F9AE9A9045BACED04A05A2_CE2C3A6B_18978.jpg" /></a></div>
# 	<div class="txt">
# 		<a href="info/1063/9009.htm" target="_blank" class="tit" title="我校召开专业群建设交流与研讨会">我校召开专业群建设交流与研讨会</a>
# 	</div>
# </li>
# <script>_showDynClickBatch(['dynclicks_u13_9014','dynclicks_u13_9013','dynclicks_u13_9012','dynclicks_u13_9011','dynclicks_u13_9010','dynclicks_u13_9009'],[9014,9013,9012,9011,9010,9009],"wbnews", 1409161160)</script>
# </ul>
# <ul><li name="one" class="clearfix box">
# 	<div class="img"><a href="info/1133/9251.htm" target="_blank"><img src="/__local/0/67/FE/B00F2F244771EE3F81BAE8D5B26_6FAF8CEC_15E83.jpg" /></a></div>
# 	<div class="txt">
# 		<a href="info/1133/9251.htm" target="_blank" class="tit" title="2020年“一带一路”职业教育国际研讨会在我校召开">2020年“一带一路”职业教育国际研讨会在我校召开</a>
# 		<p class="zhaiyao">以“数字职教建设 共商共建共享”为主题的2020年“一带一路”职业教育国际研讨会在深圳召开。11月26-27日，以“数字职教建设 ...</p>
# 		<a href="info/1133/9251.htm" target="_blank" class="more"><img src="images/more_02.png" /></a>
# 	</div>
# </li>
# <li name="two" class="clearfix nomaright box">
# 	<div class="img"><a href="info/1133/9005.htm" target="_blank"><img src="/__local/E/BD/B4/0C01B5C627DBC6F2D320F27C5FE_7CD2871F_8FF54.png" /></a></div>
# 	<div class="txt">
# 		<a href="info/1133/9005.htm" target="_blank" class="tit" title="国际网络教育学院（IIOE）在云端发布">国际网络教育学院（IIOE）在云端发布</a>
# 		<div class="xiaoxun">
# 			<img src="images/pic_xiaoxun_2.png" />
# 		</div>
# 	</div>
# </li>
# <li name="other" class="box bg-3 ">
# 	<div class="img"><a href="info/1133/8083.htm" target="_blank"><img src="/__local/7/B4/26/1AD1E6AE1429E3FC4FB769DA00C_9F3D3E7C_1F2AB.jpg" /></a></div>
# 	<div class="txt">
# 		<a href="info/1133/8083.htm" target="_blank" class="tit" title="南非Southern LABS及华为代表团来校访问">南非Southern LABS及华为代表团来校访问</a>
# 	</div>
# </li>
# <li name="other" class="box bg-4 ">
# 	<div class="img"><a href="info/1133/8026.htm" target="_blank"><img src="/__local/4/3A/D2/4E17638B43E7A7F3F8C4016E114_FD758235_1F981.jpg" /></a></div>
# 	<div class="txt">
# 		<a href="info/1133/8026.htm" target="_blank" class="tit" title="学校举行多糖科学及保健和生物材料应用国际会议">学校举行多糖科学及保健和生物材料应用国际会议</a>
# 	</div>
# </li>
# <li name="other" class="box bg-5 ">
# 	<div class="img"><a href="info/1133/8024.htm" target="_blank"><img src="/__local/A/03/63/A20E5919FD58EB2CF6F5A74D2A6_6422FFAD_8DE53.jpg" /></a></div>
# 	<div class="txt">
# 		<a href="info/1133/8024.htm" target="_blank" class="tit" title="我校与教科文高等教育创新中心签署合作意向书">我校与教科文高等教育创新中心签署合作意向书</a>
# 	</div>
# </li>
# <li name="other" class="box bg-6 nomaright">
# 	<div class="img"><a href="info/1133/8022.htm" target="_blank"><img src="/__local/2/7B/A9/513012D2E458A4EA12019270011_55B732AB_12D01.jpg" /></a></div>
# 	<div class="txt">
# 		<a href="info/1133/8022.htm" target="_blank" class="tit" title="马来西亚雪兰莪货运及物流报关行协会总会长拿督谢汉廷一行来访我校">马来西亚雪兰莪货运及物流报关行协会总会长拿督谢汉廷一行来...</a>
# 	</div>
# </li>
# <script>_showDynClickBatch(['dynclicks_u14_9251','dynclicks_u14_9005','dynclicks_u14_8083','dynclicks_u14_8026','dynclicks_u14_8024','dynclicks_u14_8022'],[9251,9005,8083,8026,8024,8022],"wbnews", 1409161160)</script>
# </ul></div></div><script type="text/javascript">
# 				jQuery(".slideTxtBox").slide();
# 			</script></div>
# <div class="links con2 martop10">
# <div class="picScroll-left"><div class="hd">
# 	<a class="next"></a>
# 	<a class="prev"></a>
# </div>
# <div class="bd">
# 	<ul class="picList">
# 				<li>
# 			<div class="pic">
# 				<a href="http://zhaobiao.szpt.edu.cn/" target="_blank" onmouseover="this.style.background='url(images/link_icon_1_on.png) top left';" onmouseout="this.style.background='url(images/link_icon_1.png)';" style="background: url(images/link_icon_1.png)"></a>
# 			</div>
# 			<div class="title">
# 				<a href="http://zhaobiao.szpt.edu.cn/" target="_blank">招标采购</a>
# 			</div>
# 		</li>
# 		<li>
# 			<div class="pic">
# 				<a href="kstongd/xmsqyys.htm" target="_blank" onmouseover="this.style.background='url(images/link_icon_9_on.png) top left';" onmouseout="this.style.background='url(images/link_icon_9.png)';" style="background: url(images/link_icon_9.png)"></a>
# 			</div>
# 			<div class="title">
# 				<a href="kstongd/xmsqyys.htm" target="_blank">项目申请与验收</a>
# 			</div>
# 		</li>
# 		<li>
# 			<div class="pic">
# 				<a href="http://zhaosheng.szpt.edu.cn/" target="_blank" onmouseover="this.style.background='url(images/link_icon_2_on.png) top left';" onmouseout="this.style.background='url(images/link_icon_2.png)';" style="background: url(images/link_icon_2.png)"></a>
# 			</div>
# 			<div class="title">
# 				<a href="http://zhaosheng.szpt.edu.cn/" target="_blank">招生信息</a>
# 			</div>
# 		</li>
# 		<li>
# 			<div class="pic">
# 				<a href="https://i.szpt.edu.cn" target="_blank" onmouseover="this.style.background='url(images/link_icon_ywtb_on.png) top left';" onmouseout="this.style.background='url(images/link_icon_ywtb.png)';" style="background: url(images/link_icon_ywtb.png)"></a>
# 			</div>
# 			<div class="title">
# 				<a href="https://i.szpt.edu.cn" target="_blank">一网通办</a>
# 			</div>
# 		</li>
# 		<li>
# 			<div class="pic">
# 				<a href="jyjx/rczp.htm" target="_blank" onmouseover="this.style.background='url(images/link_icon_10_on.png) top left';" onmouseout="this.style.background='url(images/link_icon_10.png)';" style="background: url(images/link_icon_10.png)"></a>
# 			</div>
# 			<div class="title">
# 				<a href="jyjx/rczp.htm" target="_blank">人才招聘</a>
# 			</div>
# 		</li>
# 		<li>
# 			<div class="pic">
# 				<a href="xxgk1/jbxx.htm" target="_blank" onmouseover="this.style.background='url(images/link_icon_3_on.png) top left';" onmouseout="this.style.background='url(images/link_icon_3.png)';" style="background: url(images/link_icon_3.png)"></a>
# 			</div>
# 			<div class="title">
# 				<a href="xxgk1/jbxx.htm" target="_blank">信息公开</a>
# 			</div>
# 		</li>
# 		<li>
# 			<div class="pic">
# 				<a href="xxgk1/cwzc/yjs.htm" target="_blank" onmouseover="this.style.background='url(images/link_icon_11_on.png) top left';" onmouseout="this.style.background='url(images/link_icon_11.png)';" style="background: url(images/link_icon_11.png)"></a>
# 			</div>
# 			<div class="title">
# 				<a href="xxgk1/cwzc/yjs.htm" target="_blank">预决算公开</a>
# 			</div>
# 		</li>
# 		<li>
# 			<div class="pic">
# 				<a href="http://jijinhui.szpt.edu.cn/" target="_blank" onmouseover="this.style.background='url(images/link_icon_5_on.png) top left';" onmouseout="this.style.background='url(images/link_icon_5.png)';" style="background: url(images/link_icon_5.png)"></a>
# 			</div>
# 			<div class="title">
# 				<a href="http://jijinhui.szpt.edu.cn/" target="_blank">基金会</a>
# 			</div>
# 		</li>
# 		<li>
# 			<div class="pic">
# 				<a href="https://vpn.szpt.edu.cn/" target="_blank" onmouseover="this.style.background='url(images/link_icon_6_on.png) top left';" onmouseout="this.style.background='url(images/link_icon_6.png)';" style="background: url(images/link_icon_6.png)"></a>
# 			</div>
# 			<div class="title">
# 				<a href="https://vpn.szpt.edu.cn/" target="_blank">VPN登陆</a>
# 			</div>
# 		</li>
# 		<li>
# 			<div class="pic">
# 				<a href="http://jpkc.szpt.edu.cn" target="_blank" onmouseover="this.style.background='url(images/link_icon_7_on.png) top left';" onmouseout="this.style.background='url(images/link_icon_7.png)';" style="background: url(images/link_icon_7.png)"></a>
# 			</div>
# 			<div class="title">
# 				<a href="http://jpkc.szpt.edu.cn" target="_blank">精品课程</a>
# 			</div>
# 		</li>
# 		<li>
# 			<div class="pic">
# 				<a href="http://szpt.fanya.chaoxing.com/portal" target="_blank" onmouseover="this.style.background='url(images/link_icon_8_on.png) top left';" onmouseout="this.style.background='url(images/link_icon_8.png)';" style="background: url(images/link_icon_8.png)"></a>
# 			</div>
# 			<div class="title">
# 				<a href="http://szpt.fanya.chaoxing.com/portal" target="_blank">网络教学</a>
# 			</div>
# 		</li>
# 		<li>
# 			<div class="pic">
# 				<a href="http://www.lib.szpt.edu.cn" target="_blank" onmouseover="this.style.background='url(images/link_icon_4_on.png) top left';" onmouseout="this.style.background='url(images/link_icon_4.png)';" style="background: url(images/link_icon_4.png)"></a>
# 			</div>
# 			<div class="title">
# 				<a href="http://www.lib.szpt.edu.cn" target="_blank">图书馆</a>
# 			</div>
# 		</li>
# 	</ul>
# </div></div><script type="text/javascript">
# 				jQuery(".picScroll-left").slide({
# 					titCell: ".hd ul",
# 					mainCell: ".bd ul",
# 					autoPage: true,
# 					effect: "left",
# 					autoPlay: true,
# 					vis: 9,
# 					trigger: "click"
# 				});
# 			</script></div>
# <div class="footer">
# <div class="con2 clearfix">
# <div class="yqlink_left fl"><a href="http://edu.gd.gov.cn" target="_blank" title="" onclick="_addDynClicks(&#34;wburl&#34;, 1409161160, 37683)">广东省教育厅</a>
# <a href="http://szeb.sz.gov.cn" target="_blank" title="" onclick="_addDynClicks(&#34;wburl&#34;, 1409161160, 37684)">深圳市教育局</a>
# <a href="http://www.tech.net.cn/" target="_blank" title="" onclick="_addDynClicks(&#34;wburl&#34;, 1409161160, 37685)">中国高职高专教育网</a>
# <a href="https://unevoc.unesco.org/" target="_blank" title="" onclick="_addDynClicks(&#34;wburl&#34;, 1409161160, 38378)">教科文国际职教中心</a>
# </div>
# <div class="yqlink_right fr"><ul id="nav">
# 		<li class="mainlevel">
# 		<a href="javascript:;" target="_blank" title="二级学院网站导航列表"><span><img src="images/link_select_1.png" /></span>二级学院网站导航列表</a>
# 		<ul>
# 			<li>
# 				<a href="http://EI.szpt.edu.cn" target="_blank" title="电子与通信工程学院">电子与通信工程学院</a>
# 			</li>
# 			<li>
# 				<a href="http://ce.szpt.edu.cn" target="_blank" title="人工智能学院">人工智能学院</a>
# 			</li>
# 			<li>
# 				<a href="http://www.jszx.szpt.edu.cn" target="_blank" title="计算机基础教学部">计算机基础教学部</a>
# 			</li>
# 			<li>
# 				<a href="https://jdxy.szpt.edu.cn" target="_blank" title="机电工程学院">机电工程学院</a>
# 			</li>
# 			<li>
# 				<a href="https://econ.szpt.edu.cn" target="_blank" title="经济学院">经济学院</a>
# 			</li>
# 			<li>
# 				<a href="http://glxy.szpt.edu.cn" target="_blank" title="管理学院">管理学院</a>
# 			</li>
# 			<li>
# 				<a href="https://zhaobiao.szpt.edu.cn" target="_blank" title="采购中心">采购中心</a>
# 			</li>
# 			<li>
# 				<a href="http://fao.szpt.edu.cn" target="_blank" title="外事处">外事处</a>
# 			</li>
# 			<li>
# 				<a href="http://sbc.szpt.edu.cn" target="_blank" title="国有资产管理处">国有资产管理处</a>
# 			</li>
# 			<li>
# 				<a href="http://hjc.szpt.edu.cn" target="_blank" title="后勤基建处">后勤基建处</a>
# 			</li>
# 			<li>
# 				<a href="https://bwc.szpt.edu.cn" target="_blank" title="保卫处">保卫处</a>
# 			</li>
# 			<li>
# 				<a href="http://dudao.szpt.edu.cn" target="_blank" title="质量保障中心">质量保障中心</a>
# 			</li>
# 			<li>
# 				<a href="http://www.lib.szpt.edu.cn" target="_blank" title="图书馆">图书馆</a>
# 			</li>
# 			<li>
# 				<a href="https://etic.szpt.edu.cn" target="_blank" title="教育技术与信息中心">教育技术与信息中心</a>
# 			</li>
# 			<li>
# 				<a href="http://zjs.szpt.edu.cn" target="_blank" title="技术与职业教育研究所">技术与职业教育研究所</a>
# 			</li>
# 		</ul>
# 	</li>
# </ul><script type="text/javascript">
# 						$(document).ready(function() {
# 							$('li.mainlevel').mousemove(function() {
# 								$(this).find('ul').slideDown(); //you can give it a speed
# 							});
# 							$('li.mainlevel').mouseleave(function() {
# 								$(this).find('ul').slideUp("fast");
# 							});
# 						});
# 					</script></div></div>
# <div class="con2 clearfix">
# <div class="foot-logo fl martopbot23">    <img src="images/foot_logo.png" />
# </div>
# <div class="add fl martopbot23"><script language="javascript" src="/system/resource/js/news/mp4video.js"></script>
# <p>学院地址：广东省深圳市南山区留仙大道7098号&nbsp; &nbsp;邮编：518055</p>
# <p>联系电话：26019709/26731842&nbsp; &nbsp; 传真：26731712</p>
# <span id="_ideConac"><a href="http://bszs.conac.cn/sitename?method=show&id=095EB8D099755559E053022819AC32FE" target="_blank"><img id="imgConac" vspace="0" hspace="0" border="0" src="images/blue.png" data-bd-imgshare-binded="1"></a></span>
#
# <a href="https://unevoc.unesco.org/"><img src="images/huiyi.png" style="width:150px;"></a>
# </div>
# <div class="ewm fr martopbot23 clearfix">    <span>
# <a href="https://weibo.com/shenzhenpolytechnic" title="官方微博" onclick="_addDynClicks(&#34;wbimage&#34;, 1409161160, 40852)" target="_blank"><img src="images/szpt-weixin.png" /></a><br>
# <a href="https://weibo.com/shenzhenpolytechnic" title="官方微博" onclick="_addDynClicks(&#34;wbimage&#34;, 1409161160, 40852)" target="_blank">官方微博</a>
# </span>
# <span>
# <a href="" title="官方微信" onclick="_addDynClicks(&#34;wbimage&#34;, 1409161160, 36951)" target="_blank"><img src="images/szpt-weibo.png" /></a><br>
# <a href="" title="官方微信" onclick="_addDynClicks(&#34;wbimage&#34;, 1409161160, 36951)" target="_blank">官方微信</a>
# </span>
# </div></div>
# <div class="con2 clearfix">
# <div class="copyright"><!-- 版权内容请在本组件"内容配置-版权"处填写 -->
# <div class="recordNumber">Copyright © SHENZHEN POLYTECHNIC. All Rights Reserved &nbsp;备案号：<a href="http://beian.miit.gov.cn">粤ICP备15008843号-1</a> <a href="http://www.beian.gov.cn/portal/index.do">深公网安备4403101901260</a></div></div>
# <div class="back"><a class="to-top">返回顶部<img src="images/icon_back.png" /></a></div></div></div><script type="text/javascript" src="js/jquery.toTop.min.js"></script><script type="text/javascript" src="js/index.js"></script>
#
# </body></html>

# %%
# 异常处理

# %% [markdown]
# ### requests获取网页的练习
# - 豆瓣电影250

# %%
# 获取豆瓣电影250首页
import requests
url = "https://movie.douban.com/top250"
head = {"User-Agent": "Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.135 Safari/537.36"}
r = requests.get(url, headers=head)
r.encoding = r.apparent_encoding
print(r.text)
# Out:
# <!DOCTYPE html>
# <html lang="zh-CN" class="ua-windows ua-webkit">
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#     <meta name="renderer" content="webkit">
#     <meta name="referrer" content="always">
#     <meta name="google-site-verification" content="ok0wCgT20tBBgo9_zat2iAcimtN4Ftf5ccsh092Xeyw" />
#     <title>
# 豆瓣电影 Top 250
# </title>
#
#     <meta name="baidu-site-verification" content="cZdR4xxR7RxmM4zE" />
#     <meta http-equiv="Pragma" content="no-cache">
#     <meta http-equiv="Expires" content="Sun, 6 Mar 2005 01:00:00 GMT">
#
#     <link rel="apple-touch-icon" href="https://img3.doubanio.com/f/movie/d59b2715fdea4968a450ee5f6c95c7d7a2030065/pics/movie/apple-touch-icon.png">
#     <link href="https://img3.doubanio.com/f/shire/859dba5cddc7ed1435808cf5a8ddde5792cd6e0c/css/douban.css" rel="stylesheet" type="text/css">
#     <link href="https://img3.doubanio.com/f/shire/db02bd3a4c78de56425ddeedd748a6804af60ee9/css/separation/_all.css" rel="stylesheet" type="text/css">
#     <link href="https://img3.doubanio.com/f/movie/252bef058b97005c6a41e8f1b9f7b06b84bc71b3/css/movie/base/init.css" rel="stylesheet">
#     <script type="text/javascript">var _head_start = new Date();</script>
#     <script type="text/javascript" src="https://img3.doubanio.com/f/movie/0495cb173e298c28593766009c7b0a953246c5b5/js/movie/lib/jquery.js"></script>
#     <script type="text/javascript" src="https://img3.doubanio.com/f/shire/5ecaf46d6954d5a30bc7d99be86ae34031646e00/js/douban.js"></script>
#     <script type="text/javascript" src="https://img3.doubanio.com/f/shire/0efdc63b77f895eaf85281fb0e44d435c6239a3f/js/separation/_all.js"></script>
#
# <link href="https://img3.doubanio.com/f/movie/2c95f768ea74284b900c04c0209b0a44f0a0de52/css/movie/top_movies.css" rel="stylesheet" type="text/css" />
# <script type="text/javascript" src="https://img3.doubanio.com/f/shire/77323ae72a612bba8b65f845491513ff3329b1bb/js/do.js" data-cfg-autoload="false"></script>
# <script type='text/javascript'>
#     Do.ready(function(){
#             $("#mine-selector input[type='checkbox']").click(function(){
#                 var val = $(this).is(":checked")?$(this).val():"";
#                 window.location.href = '/top250?filter=' + val;
#             })
#     })
# </script>
#
#     <style type="text/css">
# .site-nav-logo img{margin-bottom:0;}
# </style>
#     <style type="text/css">img { max-width: 100%; }</style>
#     <script type="text/javascript"></script>
#     <link rel="stylesheet" href="https://img3.doubanio.com/misc/mixed_static/562925b5e3824700.css">
#
#     <link rel="shortcut icon" href="https://img3.doubanio.com/favicon.ico" type="image/x-icon">
# </head>
#
# <body>
#
#     <script type="text/javascript">var _body_start = new Date();</script>
#
#
#
#
#
#
#     <link href="//img3.doubanio.com/dae/accounts/resources/d3e2921/shire/bundle.css" rel="stylesheet" type="text/css">
#
#
#
# <div id="db-global-nav" class="global-nav">
#   <div class="bd">
#
# <div class="top-nav-info">
#   <a href="https://accounts.douban.com/passport/login?source=movie" class="nav-login" rel="nofollow">登录/注册</a>
# </div>
#
#
#     <div class="top-nav-doubanapp">
#   <a href="https://www.douban.com/doubanapp/app?channel=top-nav" class="lnk-doubanapp">下载豆瓣客户端</a>
#   <div id="doubanapp-tip">
#     <a href="https://www.douban.com/doubanapp/app?channel=qipao" class="tip-link">豆瓣 <span class="version">6.0</span> 全新发布</a>
#     <a href="javascript: void 0;" class="tip-close">×</a>
#   </div>
#   <div id="top-nav-appintro" class="more-items">
#     <p class="appintro-title">豆瓣</p>
#     <p class="qrcode">扫码直接下载</p>
#     <div class="download">
#       <a href="https://www.douban.com/doubanapp/redirect?channel=top-nav&direct_dl=1&download=iOS">iPhone</a>
#       <span>·</span>
#       <a href="https://www.douban.com/doubanapp/redirect?channel=top-nav&direct_dl=1&download=Android" class="download-android">Android</a>
#     </div>
#   </div>
# </div>
#
#
#
#
# <div class="global-nav-items">
#   <ul>
#     <li class="">
#       <a href="https://www.douban.com" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-main&quot;,&quot;uid&quot;:&quot;0&quot;}">豆瓣</a>
#     </li>
#     <li class="">
#       <a href="https://book.douban.com" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-book&quot;,&quot;uid&quot;:&quot;0&quot;}">读书</a>
#     </li>
#     <li class="on">
#       <a href="https://movie.douban.com"  data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-movie&quot;,&quot;uid&quot;:&quot;0&quot;}">电影</a>
#     </li>
#     <li class="">
#       <a href="https://music.douban.com" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-music&quot;,&quot;uid&quot;:&quot;0&quot;}">音乐</a>
#     </li>
#     <li class="">
#       <a href="https://www.douban.com/location" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-location&quot;,&quot;uid&quot;:&quot;0&quot;}">同城</a>
#     </li>
#     <li class="">
#       <a href="https://www.douban.com/group" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-group&quot;,&quot;uid&quot;:&quot;0&quot;}">小组</a>
#     </li>
#     <li class="">
#       <a href="https://read.douban.com&#47;?dcs=top-nav&amp;dcm=douban" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-read&quot;,&quot;uid&quot;:&quot;0&quot;}">阅读</a>
#     </li>
#     <li class="">
#       <a href="https://douban.fm&#47;?from_=shire_top_nav" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-fm&quot;,&quot;uid&quot;:&quot;0&quot;}">FM</a>
#     </li>
#     <li class="">
#       <a href="https://time.douban.com&#47;?dt_time_source=douban-web_top_nav" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-time&quot;,&quot;uid&quot;:&quot;0&quot;}">时间</a>
#     </li>
#     <li class="">
#       <a href="https://market.douban.com&#47;?utm_campaign=douban_top_nav&amp;utm_source=douban&amp;utm_medium=pc_web" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-market&quot;,&quot;uid&quot;:&quot;0&quot;}">豆品</a>
#     </li>
#   </ul>
# </div>
#
#   </div>
# </div>
# <script>
#   ;window._GLOBAL_NAV = {
#     DOUBAN_URL: "https://www.douban.com",
#     N_NEW_NOTIS: 0,
#     N_NEW_DOUMAIL: 0
#   };
# </script>
#
#
#
#     <script src="//img3.doubanio.com/dae/accounts/resources/d3e2921/shire/bundle.js" defer="defer"></script>
#
#
#
#
#
#
#
#
#     <link href="//img3.doubanio.com/dae/accounts/resources/d3e2921/movie/bundle.css" rel="stylesheet" type="text/css">
#
#
#
#
# <div id="db-nav-movie" class="nav">
#   <div class="nav-wrap">
#   <div class="nav-primary">
#     <div class="nav-logo">
#       <a href="https:&#47;&#47;movie.douban.com">豆瓣电影</a>
#     </div>
#     <div class="nav-search">
#       <form action="https:&#47;&#47;search.douban.com&#47;movie/subject_search" method="get">
#         <fieldset>
#           <legend>搜索：</legend>
#           <label for="inp-query">
#           </label>
#           <div class="inp"><input id="inp-query" name="search_text" size="22" maxlength="60" placeholder="搜索电影、电视剧、综艺、影人" value=""></div>
#           <div class="inp-btn"><input type="submit" value="搜索"></div>
#           <input type="hidden" name="cat" value="1002" />
#         </fieldset>
#       </form>
#     </div>
#   </div>
#   </div>
#   <div class="nav-secondary">
#
#
# <div class="nav-items">
#   <ul>
#     <li    ><a href="https://movie.douban.com/cinema/nowplaying/"
#      >影讯&购票</a>
#     </li>
#     <li    ><a href="https://movie.douban.com/explore"
#      >选电影</a>
#     </li>
#     <li    ><a href="https://movie.douban.com/tv/"
#      >电视剧</a>
#     </li>
#     <li    ><a href="https://movie.douban.com/chart"
#      >排行榜</a>
#     </li>
#     <li    ><a href="https://movie.douban.com/tag/"
#      >分类</a>
#     </li>
#     <li    ><a href="https://movie.douban.com/review/best/"
#      >影评</a>
#     </li>
#     <li    ><a href="https://movie.douban.com/annual/2020?source=navigation"
#      >2020年度榜单</a>
#     </li>
#     <li    ><a href="https://m.douban.com/standbyme/annual2019?source=navigation"
#             target="_blank"
#      >2019书影音报告</a>
#     </li>
#   </ul>
# </div>
#
#     <a href="https://movie.douban.com/annual/2020?source=movie_navigation" class="movieannual"></a>
#   </div>
# </div>
#
# <script id="suggResult" type="text/x-jquery-tmpl">
#   <li data-link="{{= url}}">
#             <a href="{{= url}}" onclick="moreurl(this, {from:'movie_search_sugg', query:'{{= keyword }}', subject_id:'{{= id}}', i: '{{= index}}', type: '{{= type}}'})">
#             <img src="{{= img}}" width="40" />
#             <p>
#                 <em>{{= title}}</em>
#                 {{if year}}
#                     <span>{{= year}}</span>
#                 {{/if}}
#                 {{if sub_title}}
#                     <br /><span>{{= sub_title}}</span>
#                 {{/if}}
#                 {{if address}}
#                     <br /><span>{{= address}}</span>
#                 {{/if}}
#                 {{if episode}}
#                     {{if episode=="unknow"}}
#                         <br /><span>集数未知</span>
#                     {{else}}
#                         <br /><span>共{{= episode}}集</span>
#                     {{/if}}
#                 {{/if}}
#             </p>
#         </a>
#         </li>
#   </script>
#
#
#
#
#     <script src="//img3.doubanio.com/dae/accounts/resources/d3e2921/movie/bundle.js" defer="defer"></script>
#
#
#
#
#
#
#     <div id="wrapper">
#
#
#
#     <div id="content">
#
#     <h1>豆瓣电影 Top 250</h1>
#
#         <div class="grid-16-8 clearfix">
#
#
#             <div class="article">
#
#
#
#
#
#
#
#
# <div class="opt mod">
#     <div class="tabs">
#
#
#
#     </div>
#     <span id="mine-selector">
#       <input type="checkbox"  value="unwatched">我没看过的
#     </span>
# </div>
#
#
#
# <ol class="grid_view">
#         <li>
#             <div class="item">
#                 <div class="pic">
#                     <em class="">1</em>
#                     <a href="https://movie.douban.com/subject/1292052/">
#                         <img width="100" alt="肖申克的救赎" src="https://img2.doubanio.com/view/photo/s_ratio_poster/public/p480747492.jpg" class="">
#                     </a>
#                 </div>
#                 <div class="info">
#                     <div class="hd">
#                         <a href="https://movie.douban.com/subject/1292052/" class="">
#                             <span class="title">肖申克的救赎</span>
#                                     <span class="title">&nbsp;/&nbsp;The Shawshank Redemption</span>
#                                 <span class="other">&nbsp;/&nbsp;月黑高飞(港)  /  刺激1995(台)</span>
#                         </a>
#
#
#                             <span class="playable">[可播放]</span>
#                     </div>
#                     <div class="bd">
#                         <p class="">
#                             导演: 弗兰克·德拉邦特 Frank Darabont&nbsp;&nbsp;&nbsp;主演: 蒂姆·罗宾斯 Tim Robbins /...<br>
#                             1994&nbsp;/&nbsp;美国&nbsp;/&nbsp;犯罪 剧情
#                         </p>
#
#
#                         <div class="star">
#                                 <span class="rating5-t"></span>
#                                 <span class="rating_num" property="v:average">9.7</span>
#                                 <span property="v:best" content="10.0"></span>
#                                 <span>2220628人评价</span>
#                         </div>
#
#                             <p class="quote">
#                                 <span class="inq">希望让人自由。</span>
#                             </p>
#                     </div>
#                 </div>
#             </div>
#         </li>
#         <li>
#             <div class="item">
#                 <div class="pic">
#                     <em class="">2</em>
#                     <a href="https://movie.douban.com/subject/1291546/">
#                         <img width="100" alt="霸王别姬" src="https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2561716440.jpg" class="">
#                     </a>
#                 </div>
#                 <div class="info">
#                     <div class="hd">
#                         <a href="https://movie.douban.com/subject/1291546/" class="">
#                             <span class="title">霸王别姬</span>
#                                 <span class="other">&nbsp;/&nbsp;再见，我的妾  /  Farewell My Concubine</span>
#                         </a>
#
#
#                             <span class="playable">[可播放]</span>
#                     </div>
#                     <div class="bd">
#                         <p class="">
#                             导演: 陈凯歌 Kaige Chen&nbsp;&nbsp;&nbsp;主演: 张国荣 Leslie Cheung / 张丰毅 Fengyi Zha...<br>
#                             1993&nbsp;/&nbsp;中国大陆 中国香港&nbsp;/&nbsp;剧情 爱情 同性
#                         </p>
#
#
#                         <div class="star">
#                                 <span class="rating5-t"></span>
#                                 <span class="rating_num" property="v:average">9.6</span>
#                                 <span property="v:best" content="10.0"></span>
#                                 <span>1647948人评价</span>
#                         </div>
#
#                             <p class="quote">
#                                 <span class="inq">风华绝代。</span>
#                             </p>
#                     </div>
#                 </div>
#             </div>
#         </li>
#         <li>
#             <div class="item">
#                 <div class="pic">
#                     <em class="">3</em>
#                     <a href="https://movie.douban.com/subject/1292720/">
#                         <img width="100" alt="阿甘正传" src="https://img2.doubanio.com/view/photo/s_ratio_poster/public/p2372307693.jpg" class="">
#                     </a>
#                 </div>
#                 <div class="info">
#                     <div class="hd">
#                         <a href="https://movie.douban.com/subject/1292720/" class="">
#                             <span class="title">阿甘正传</span>
#                                     <span class="title">&nbsp;/&nbsp;Forrest Gump</span>
#                                 <span class="other">&nbsp;/&nbsp;福雷斯特·冈普</span>
#                         </a>
#
#
#                             <span class="playable">[可播放]</span>
#                     </div>
#                     <div class="bd">
#                         <p class="">
#                             导演: 罗伯特·泽米吉斯 Robert Zemeckis&nbsp;&nbsp;&nbsp;主演: 汤姆·汉克斯 Tom Hanks / ...<br>
#                             1994&nbsp;/&nbsp;美国&nbsp;/&nbsp;剧情 爱情
#                         </p>
#
#
#                         <div class="star">
#                                 <span class="rating5-t"></span>
#                                 <span class="rating_num" property="v:average">9.5</span>
#                                 <span property="v:best" content="10.0"></span>
#                                 <span>1673149人评价</span>
#                         </div>
#
#                             <p class="quote">
#                                 <span class="inq">一部美国近现代史。</span>
#                             </p>
#                     </div>
#                 </div>
#             </div>
#         </li>
#         <li>
#             <div class="item">
#                 <div class="pic">
#                     <em class="">4</em>
#                     <a href="https://movie.douban.com/subject/1295644/">
#                         <img width="100" alt="这个杀手不太冷" src="https://img3.doubanio.com/view/photo/s_ratio_poster/public/p511118051.jpg" class="">
#                     </a>
#                 </div>
#                 <div class="info">
#                     <div class="hd">
#                         <a href="https://movie.douban.com/subject/1295644/" class="">
#                             <span class="title">这个杀手不太冷</span>
#                                     <span class="title">&nbsp;/&nbsp;Léon</span>
#                                 <span class="other">&nbsp;/&nbsp;杀手莱昂  /  终极追杀令(台)</span>
#                         </a>
#
#
#                     </div>
#                     <div class="bd">
#                         <p class="">
#                             导演: 吕克·贝松 Luc Besson&nbsp;&nbsp;&nbsp;主演: 让·雷诺 Jean Reno / 娜塔莉·波特曼 ...<br>
#                             1994&nbsp;/&nbsp;法国 美国&nbsp;/&nbsp;剧情 动作 犯罪
#                         </p>
#
#
#                         <div class="star">
#                                 <span class="rating45-t"></span>
#                                 <span class="rating_num" property="v:average">9.4</span>
#                                 <span property="v:best" content="10.0"></span>
#                                 <span>1857748人评价</span>
#                         </div>
#
#                             <p class="quote">
#                                 <span class="inq">怪蜀黍和小萝莉不得不说的故事。</span>
#                             </p>
#                     </div>
#                 </div>
#             </div>
#         </li>
#         <li>
#             <div class="item">
#                 <div class="pic">
#                     <em class="">5</em>
#                     <a href="https://movie.douban.com/subject/1292722/">
#                         <img width="100" alt="泰坦尼克号" src="https://img9.doubanio.com/view/photo/s_ratio_poster/public/p457760035.jpg" class="">
#                     </a>
#                 </div>
#                 <div class="info">
#                     <div class="hd">
#                         <a href="https://movie.douban.com/subject/1292722/" class="">
#                             <span class="title">泰坦尼克号</span>
#                                     <span class="title">&nbsp;/&nbsp;Titanic</span>
#                                 <span class="other">&nbsp;/&nbsp;铁达尼号(港 / 台)</span>
#                         </a>
#
#
#                             <span class="playable">[可播放]</span>
#                     </div>
#                     <div class="bd">
#                         <p class="">
#                             导演: 詹姆斯·卡梅隆 James Cameron&nbsp;&nbsp;&nbsp;主演: 莱昂纳多·迪卡普里奥 Leonardo...<br>
#                             1997&nbsp;/&nbsp;美国&nbsp;/&nbsp;剧情 爱情 灾难
#                         </p>
#
#
#                         <div class="star">
#                                 <span class="rating45-t"></span>
#                                 <span class="rating_num" property="v:average">9.4</span>
#                                 <span property="v:best" content="10.0"></span>
#                                 <span>1630919人评价</span>
#                         </div>
#
#                             <p class="quote">
#                                 <span class="inq">失去的才是永恒的。 </span>
#                             </p>
#                     </div>
#                 </div>
#             </div>
#         </li>
#         <li>
#             <div class="item">
#                 <div class="pic">
#                     <em class="">6</em>
#                     <a href="https://movie.douban.com/subject/1292063/">
#                         <img width="100" alt="美丽人生" src="https://img2.doubanio.com/view/photo/s_ratio_poster/public/p
span>
#                         </a>
#
#
#                             <span class="playable">[可播放]</span>
#                     </div>
#                     <div class="bd">
#                         <p class="">
#                             导演: 弗朗西斯·福特·科波拉 Francis Ford Coppola&nbsp;&nbsp;&nbsp;主演: 马龙·白兰度 M...<br>
#                             1972&nbsp;/&nbsp;美国&nbsp;/&nbsp;剧情 犯罪
#                         </p>
#
#
#                         <div class="star">
#                                 <span class="rating45-t"></span>
#                                 <span class="rating_num" property="v:average">9.3</span>
#                                 <span property="v:best" content="10.0"></span>
#                                 <span>725486人评价</span>
#                         </div>
#
#                             <p class="quote">
#                                 <span class="inq">千万不要记恨你的对手，这样会让你失去理智。</span>
#                             </p>
#                     </div>
#                 </div>
#             </div>
#         </li>
#         <li>
#             <div class="item">
#                 <div class="pic">
#                     <em class="">22</em>
#                     <a href="https://movie.douban.com/subject/1291560/">
#                         <img width="100" alt="龙猫" src="https://img9.doubanio.com/view/photo/s_ratio_poster/public/p2540924496.jpg" class="">
#                     </a>
#                 </div>
#                 <div class="info">
#                     <div class="hd">
#                         <a href="https://movie.douban.com/subject/1291560/" class="">
#                             <span class="title">龙猫</span>
#                                     <span class="title">&nbsp;/&nbsp;となりのトトロ</span>
#                                 <span class="other">&nbsp;/&nbsp;邻居托托罗  /  邻家的豆豆龙</span>
#                         </a>
#
#
#                             <span class="playable">[可播放]</span>
#                     </div>
#                     <div class="bd">
#                         <p class="">
#                             导演: 宫崎骏 Hayao Miyazaki&nbsp;&nbsp;&nbsp;主演: 日高法子 Noriko Hidaka / 坂本千夏 Ch...<br>
#                             1988&nbsp;/&nbsp;日本&nbsp;/&nbsp;动画 奇幻 冒险
#                         </p>
#
#
#                         <div class="star">
#                                 <span class="rating45-t"></span>
#                                 <span class="rating_num" property="v:average">9.2</span>
#                                 <span property="v:best" content="10.0"></span>
#                                 <span>990287人评价</span>
#                         </div>
#
#                             <p class="quote">
#                                 <span class="inq">人人心中都有个龙猫，童年就永远不会消失。</span>
#                             </p>
#                     </div>
#                 </div>
#             </div>
#         </li>
#         <li>
#             <div class="item">
#                 <div class="pic">
#                     <em class="">23</em>
#                     <a href="https://movie.douban.com/subject/1849031/">
#                         <img width="100" alt="当幸福来敲门" src="https://img9.doubanio.com/view/photo/s_ratio_poster/public/p2614359276.jpg" class="">
#                     </a>
#                 </div>
#                 <div class="info">
#                     <div class="hd">
#                         <a href="https://movie.douban.com/subject/1849031/" class="">
#                             <span class="title">当幸福来敲门</span>
#                                     <span class="title">&nbsp;/&nbsp;The Pursuit of Happyness</span>
#                                 <span class="other">&nbsp;/&nbsp;寻找快乐的故事(港)  /  追求快乐</span>
#                         </a>
#
#
#                             <span class="playable">[可播放]</span>
#                     </div>
#                     <div class="bd">
#                         <p class="">
#                             导演: 加布里尔·穆奇诺 Gabriele Muccino&nbsp;&nbsp;&nbsp;主演: 威尔·史密斯 Will Smith ...<br>
#                             2006&nbsp;/&nbsp;美国&nbsp;/&nbsp;剧情 传记 家庭
#                         </p>
#
#
#                         <div class="star">
#                                 <span class="rating45-t"></span>
#                                 <span class="rating_num" property="v:average">9.1</span>
#                                 <span property="v:best" content="10.0"></span>
#                                 <span>1191407人评价</span>
#                         </div>
#
#                             <p class="quote">
#                                 <span class="inq">平民励志片。 </span>
#                             </p>
#                     </div>
#                 </div>
#             </div>
#         </li>
#         <li>
#             <div class="item">
#                 <div class="pic">
#                     <em class="">24</em>
#                     <a href="https://movie.douban.com/subject/3319755/">
#                         <img width="100" alt="怦然心动" src="https://img1.doubanio.com/view/photo/s_ratio_poster/public/p501177648.jpg" class="">
#                     </a>
#                 </div>
#                 <div class="info">
#                     <div class="hd">
#                         <a href="https://movie.douban.com/subject/3319755/" class="">
#                             <span class="title">怦然心动</span>
#                                     <span class="title">&nbsp;/&nbsp;Flipped</span>
#                                 <span class="other">&nbsp;/&nbsp;萌动青春  /  青春萌动</span>
#                         </a>
#
#
#                             <span class="playable">[可播放]</span>
#                     </div>
#                     <div class="bd">
#                         <p class="">
#                             导演: 罗伯·莱纳 Rob Reiner&nbsp;&nbsp;&nbsp;主演: 玛德琳·卡罗尔 Madeline Carroll / 卡...<br>
#                             2010&nbsp;/&nbsp;美国&nbsp;/&nbsp;剧情 喜剧 爱情
#                         </p>
#
#
#                         <div class="star">
#                                 <span class="rating45-t"></span>
#                                 <span class="rating_num" property="v:average">9.1</span>
#                                 <span property="v:best" content="10.0"></span>
#                                 <span>1392522人评价</span>
#                         </div>
#
#                             <p class="quote">
#                                 <span class="inq">真正的幸福是来自内心深处。</span>
#                             </p>
#                     </div>
#                 </div>
#             </div>
#         </li>
#         <li>
#             <div class="item">
#                 <div class="pic">
#                     <em class="">25</em>
#                     <a href="https://movie.douban.com/subject/6786002/">
#                         <img width="100" alt="触不可及" src="https://img9.doubanio.com/view/photo/s_ratio_poster/public/p1454261925.jpg" class="">
#                     </a>
#                 </div>
#                 <div class="info">
#                     <div class="hd">
#                         <a href="https://movie.douban.com/subject/6786002/" class="">
#                             <span class="title">触不可及</span>
#                                     <span class="title">&nbsp;/&nbsp;Intouchables</span>
#                                 <span class="other">&nbsp;/&nbsp;闪亮人生(港)  /  逆转人生(台)</span>
#                         </a>
#
#
#                     </div>
#                     <div class="bd">
#                         <p class="">
#                             导演: 奥利维·那卡什 Olivier Nakache / 艾力克·托兰达 Eric Toledano&nbsp;&nbsp;&nbsp;主...<br>
#                             2011&nbsp;/&nbsp;法国&nbsp;/&nbsp;剧情 喜剧
#                         </p>
#
#
#                         <div class="star">
#                                 <span class="rating45-t"></span>
#                                 <span class="rating_num" property="v:average">9.2</span>
#                                 <span property="v:best" content="10.0"></span>
#                                 <span>771715人评价</span>
#                         </div>
#
#                             <p class="quote">
#                                 <span class="inq">满满温情的高雅喜剧。</span>
#                             </p>
#                     </div>
#                 </div>
#             </div>
#         </li>
# </ol>
#
#
#
#
#
#
#
#         <div class="paginator">
#         <span class="prev">
#             &lt;前页
#         </span>
#
#
#
#                 <span class="thispage">1</span>
#
#             <a href="?start=25&amp;filter=" >2</a>
#
#
#             <a href="?start=50&amp;filter=" >3</a>
#
#
#             <a href="?start=75&amp;filter=" >4</a>
#
#
#             <a href="?start=100&amp;filter=" >5</a>
#
#
#             <a href="?start=125&amp;filter=" >6</a>
#
#
#             <a href="?start=150&amp;filter=" >7</a>
#
#
#             <a href="?start=175&amp;filter=" >8</a>
#
#
#             <a href="?start=200&amp;filter=" >9</a>
#
#
#             <a href="?start=225&amp;filter=" >10</a>
#
#         <span class="next">
#             <link rel="next" href="?start=25&amp;filter="/>
#             <a href="?start=25&amp;filter=" >后页&gt;</a>
#         </span>
#
#             <span class="count">(共250条)</span>
#         </div>
#
#
#
#             </div>
#             <div class="aside">
#
# <p class="pl">
#     豆瓣用户每天都在对“看过”的电影进行“很差”到“力荐”的评价，豆瓣根据每部影片看过的人数以及该影片所得的评价等综合数据，通过算法分析产生豆瓣电影 Top 250。
# </p>
#
# <div id="dale_movie_top250_bottom_right"></div>
#
# <!-- douban ad begin -->
#
#
#
#
#
#
# <div class="mobile-app-entrance block5 app-movie">
#     <a class="entrance-link" href="https://www.douban.com/doubanapp/frodo">
#         <div class="entrance-qrcode">
#             <img src="https://img3.doubanio.com/f/movie/a02f6ed325fc52e220f299d51e730c422e2bcd16/pics/movie/douban_app_ad/qrcode.png" alt="扫码下载豆瓣 App" width="80" height="80" />
#         </div>
#         <div class="entrance-info">
#             <span class="app-icon icon-movie"></span>
#             <span class="main-title">豆瓣</span>
#             <span class="sub-title">让好电影来找你</span>
#         </div>
#     </a>
# </div>
#
# <!-- douban ad end -->
#
#
#             </div>
#             <div class="extra">
#
#             </div>
#         </div>
#     </div>
#
#
#     <div id="footer">
#             <div class="footer-extra"></div>
#
# <span id="icp" class="fleft gray-link">
#     &copy; 2005－2020 douban.com, all rights reserved 北京豆网科技有限公司
# </span>
#
# <a href="https://www.douban.com/hnypt/variformcyst.py" style="display: none;"></a>
#
# <span class="fright">
#     <a href="https://www.douban.com/about">关于豆瓣</a>
#     · <a href="https://www.douban.com/jobs">在豆瓣工作</a>
#     · <a href="https://www.douban.com/about?topic=contactus">联系我们</a>
#     · <a href="https://www.douban.com/about/legal">法律声明</a>
#
#     · <a href="https://help.douban.com/?app=movie" target="_blank">帮助中心</a>
#     · <a href="https://www.douban.com/doubanapp/">移动应用</a>
#     · <a href="https://www.douban.com/partner/">豆瓣广告</a>
# </span>
#
#     </div>
#
#     </div>
#     <!-- COLLECTED JS -->
#
#
#     <link rel="stylesheet" type="text/css" href="https://img3.doubanio.com/f/shire/8377b9498330a2e6f056d863987cc7a37eb4d486/css/ui/dialog.css" />
#     <link rel="stylesheet" type="text/css" href="https://img3.doubanio.com/f/movie/4aca95d66d37ec0712b3d19973b5d8feb75f2f05/css/movie/mod/reg_login_pop.css" />
#     <script type="text/javascript" src="https://img3.doubanio.com/f/shire/77323ae72a612bba8b65f845491513ff3329b1bb/js/do.js" data-cfg-autoload="false"></script>
#     <script type="text/javascript" src="https://img3.doubanio.com/f/shire/383a6e43f2108dc69e3ff2681bc4dc6c72a5ffb0/js/ui/dialog.js"></script>
#     <script type="text/javascript">
#         var HTTPS_DB='https://www.douban.com';
# var account_pop={open:function(o,e){e?referrer="?referrer="+encodeURIComponent(e):referrer="?referrer="+window.location.href;var n="",i="",t=448;n="用户登录",i="https://accounts.douban.com/passport/login_popup?source=movie";var r=document.location.protocol+"//"+document.location.hostname,a=dui.Dialog({width:340,title:n,height:t,cls:"account_pop",isHideTitle:!0,modal:!0,content:"<iframe scrolling='no' frameborder='0' width='340' height='"+t+"' src='"+i+"' name='"+r+"'></iframe>"},!0),c=a.node;if(c.undelegate(),c.delegate(".dui-dialog-close","click",function(){var o=$("body");o.find("#login_msk").hide(),o.find(".account_pop").remove()}),$(window).width()<478){var d="";"reg"===o?d=HTTPS_DB+"/accounts/register"+referrer:"login"===o&&(d=HTTPS_DB+"/accounts/login"+referrer),window.location.href=d}else a.open();$(window).bind("message",function(o){"https://accounts.douban.com"===o.originalEvent.origin&&(c.find("iframe").css("height",o.originalEvent.data),c.height(o.originalEvent.data),a.update())})}};Douban&&Douban.init_show_login&&(Douban.init_show_login=function(o){var e=$(o);e.click(function(){var o=e.data("ref")||"";return account_pop.open("login",o),!1})}),Do(function(){$("body").delegate(".pop_register","click",function(o){o.preventDefault();var e=$(this).data("ref")||"";return account_pop.open("reg",e),!1}),$("body").delegate(".pop_login","click",function(o){o.preventDefault();var e=$(this).data("ref")||"";return account_pop.open("login",e),!1})});
#     </script>
#
#
#
#
#
#
#
#
# <script type="text/javascript">
#     (function (global) {
#         var newNode = global.document.createElement('script'),
#             existingNode = global.document.getElementsByTagName('script')[0],
#             adSource = '//erebor.douban.com/',
#             userId = '',
#             browserId = 'deybCNg7qr0',
#             criteria = '3:/top250',
#             preview = '',
#             debug = false,
#             adSlots = ['dale_movie_top250_bottom_right'];
#
#         global.DoubanAdRequest = {src: adSource, uid: userId, bid: browserId, crtr: criteria, prv: preview, debug: debug};
#         global.DoubanAdSlots = (global.DoubanAdSlots || []).concat(adSlots);
#
#         newNode.setAttribute('type', 'text/javascript');
#         newNode.setAttribute('src', '//img1.doubanio.com/czF5ODV4Ni9mL2FkanMvMjBiYWY2MDg2ZWQ0MDE1YTNmMDJhNDYxMzhmNmM0MjQxYjExYWYwMC9hZC5yZWxlYXNlLmpz');
#         newNode.setAttribute('async', true);
#         existingNode.parentNode.insertBefore(newNode, existingNode);
#     })(this);
# </script>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript">
# var _paq = _paq || [];
# _paq.push(['trackPageView']);
# _paq.push(['enableLinkTracking']);
# (function() {
#     var p=(('https:' == document.location.protocol) ? 'https' : 'http'), u=p+'://fundin.douban.com/';
#     _paq.push(['setTrackerUrl', u+'piwik']);
#     _paq.push(['setSiteId', '100001']);
#     var d=document, g=d.createElement('script'), s=d.getElementsByTagName('script')[0];
#     g.type='text/javascript';
#     g.defer=true;
#     g.async=true;
#     g.src=p+'://img3.doubanio.com/dae/fundin/piwik.js';
#     s.parentNode.insertBefore(g,s);
# })();
# </script>
#
# <script type="text/javascript">
# var setMethodWithNs = function(namespace) {
#   var ns = namespace ? namespace + '.' : ''
#     , fn = function(string) {
#         if(!ns) {return string}
#         return ns + string
#       }
#   return fn
# }
#
# var gaWithNamespace = function(fn, namespace) {
#   var method = setMethodWithNs(namespace)
#   fn.call(this, method)
# }
#
# var _gaq = _gaq || []
#   , accounts = [
#       { id: 'UA-7019765-1', namespace: 'douban' }
#     , { id: 'UA-7019765-19', namespace: '' }
#     ]
#   , gaInit = function(account) {
#       gaWithNamespace(function(method) {
#         gaInitFn.call(this, method, account)
#       }, account.namespace)
#     }
#   , gaInitFn = function(method, account) {
#       _gaq.push([method('_setAccount'), account.id]);
#       _gaq.push([method('_setSampleRate'), '5']);
#
#
#   _gaq.push([method('_addOrganic'), 'google', 'q'])
#   _gaq.push([method('_addOrganic'), 'baidu', 'wd'])
#   _gaq.push([method('_addOrganic'), 'soso', 'w'])
#   _gaq.push([method('_addOrganic'), 'youdao', 'q'])
#   _gaq.push([method('_addOrganic'), 'so.360.cn', 'q'])
#   _gaq.push([method('_addOrganic'), 'sogou', 'query'])
#   if (account.namespace) {
#     _gaq.push([method('_addIgnoredOrganic'), '豆瓣'])
#     _gaq.push([method('_addIgnoredOrganic'), 'douban'])
#     _gaq.push([method('_addIgnoredOrganic'), '豆瓣网'])
#     _gaq.push([method('_addIgnoredOrganic'), 'www.douban.com'])
#   }
#
#       if (account.namespace === 'douban') {
#         _gaq.push([method('_setDomainName'), '.douban.com'])
#       }
#
#         _gaq.push([method('_setCustomVar'), 1, 'responsive_view_mode', 'desktop', 3])
#
#         _gaq.push([method('_setCustomVar'), 2, 'login_status', '0', 2]);
#
#       _gaq.push([method('_trackPageview')])
#     }
#
# for(var i = 0, l = accounts.length; i < l; i++) {
#   var account = accounts[i]
#   gaInit(account)
# }
#
#
# ;(function() {
#     var ga = document.createElement('script');
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     ga.setAttribute('async', 'true');
#     document.documentElement.firstChild.appendChild(ga);
# })()
# </script>
#
#
#
#
#
#
#
#
#
#
#     <!-- dae-web-movie--default-54746d897f-swrj4-->
#
#   <script>_SPLITTEST=''</script>
# </body>
#
# </html>

# %% [markdown]
# #### 正则表达式解析

# %%
#

# %% [markdown]
# ### beautifulsoup4库的使用
# - beautifulsoup4 库是一个解析和处理HTML 和XML 的第三方库。
# - 使用requests 库获取HTML 页面并将其转换成字符串后，需要进一步解析HTML页面格式，提取有用信息，这需要处理HTML 和XML 的函数库。
# - beautifulsoup4 库，也称为Beautiful Soup 库或bs4 库，用于解析和处理HTML和XML。
# - beautifulsoup4 库将专业的Web 页面格式解析部分封装成函数，提供了若干有用且便捷的处理函数。
# - 可以用from…import 方式从库中直接引用BeautifulSoup 类，方法如下。
# > from bs4 import BeautifulSoup

# %% [markdown]
# #### BeautifulSoup类的常用属性

# %%
# 以学校首页为例
# title、a、div等标签属性

# %% [markdown]
# #### BeautifulSoup类常用的查找函数
# - find
# - find_all
# - select

# %% [markdown]
# #### beautifulsoup4库的应用

# %%
# 爬取学校首页的深职要闻
import requests
from bs4 import BeautifulSoup
url = "https://www.szpt.edu.cn/"
r = requests.get(url)
r.encoding = r.apparent_encoding
soup = BeautifulSoup(r.text, "lxml")
print(soup.title)
print(soup.title.string)
print(soup.title.get_text())
print(soup.a)
# Out:
# <title>深圳职业技术学院</title>
# 深圳职业技术学院
# 深圳职业技术学院
# <a href="http://english.szpt.edu.cn/" onclick='_addDynClicks("wburl", 1409161160, 37988)' title="">English</a>

# %%
soup.find("li", class_="bg_03").find("a").get_text()
# Out:
# '教工'

# %%
soup.find_all("a", target="_blank")
# Out:
# [<a href="http://email.szpt.edu.cn" onclick='_addDynClicks("wburl", 1409161160, 37992)' target="_blank" title="">教师邮箱</a>,
#  <a href="http://mail.mail.szpt.edu.cn/" onclick='_addDynClicks("wburl", 1409161160, 37993)' target="_blank" title="">学生邮箱</a>,
#  <a href="http://www.lib.szpt.edu.cn" target="_blank" title="图书馆">图书馆</a>,
#  <a href="http://szytx.szpt.edu.cn/" target="_blank" title="深职院通讯">深职院通讯</a>,
#  <a href="http://jpkc.szpt.edu.cn/rcpy/2016/" target="_blank" title="质量年报">质量年报</a>,
#  <a href="http://whyr.szpt.edu.cn" target="_blank" title="文化育人">文化育人</a>,
#  <a href="http://lhdjt.szpt.edu.cn" target="_blank" title="丽湖大讲堂">丽湖大讲堂</a>,
#  <a href="http://www.lib.szpt.edu.cn/xzfc/" target="_blank" title="深职学者">深职学者</a>,
#  <a href="http://zjs.szpt.edu.cn" target="_blank" title="技术与职业教育研究所">技术与职业教育研究所</a>,
#  <a href="http://xb.szpt.edu.cn" target="_blank" title="深职学报">深职学报</a>,
#  <a href="https://zhaosheng.szpt.edu.cn/" target="_blank" title="高考招生">高考招生</a>,
#  <a href="https://zhaosheng.szpt.edu.cn/info/1061/1931.htm" target="_blank" title="自主招生">自主招生</a>,
#  <a href="http://jiuye.szpt.edu.cn" target="_blank" title="就业指导">就业指导</a>,
#  <a href="http://fao.szpt.edu.cn" target="_blank" title="外事处">外事处</a>,
#  <a href="http://sbc.szpt.edu.cn" target="_blank" title="国有资产管理处">国有资产管理处</a>,
#  <a href="http://hjc.szpt.edu.cn" target="_blank" title="后勤基建处">后勤基建处</a>,
#  <a href="https://bwc.szpt.edu.cn" target="_blank" title="保卫处">保卫处</a>,
#  <a href="http://dudao.szpt.edu.cn" target="_blank" title="质量保障中心">质量保障中心</a>,
#  <a href="http://www.lib.szpt.edu.cn" target="_blank" title="图书馆">图书馆</a>,
#  <a href="https://etic.szpt.edu.cn" target="_blank" title="教育技术与信息中心">教育技术与信息中心</a>,
#  <a href="http://zjs.szpt.edu.cn" target="_blank" title="技术与职业教育研究所">技术与职业教育研究所</a>,
#  <a href="http://bszs.conac.cn/sitename?method=show&amp;id=095EB8D099755559E053022819AC32FE" target="_blank"><img border="0" data-bd-imgshare-binded="1" hspace="0" id="imgConac" src="images/blue.png" vspace="0"/></a>,
#  <a href="https://weibo.com/shenzhenpolytechnic" onclick='_addDynClicks("wbimage", 1409161160, 40852)' target="_blank" title="官方微博"><img src="images/szpt-weixin.png"/></a>,
#  <a href="https://weibo.com/shenzhenpolytechnic" onclick='_addDynClicks("wbimage", 1409161160, 40852)' target="_blank" title="官方微博">官方微博</a>,
#  <a href="" onclick='_addDynClicks("wbimage", 1409161160, 36951)' target="_blank" title="官方微信"><img src="images/szpt-weibo.png"/></a>,
#  <a href="" onclick='_addDynClicks("wbimage", 1409161160, 36951)' target="_blank" title="官方微信">官方微信</a>]

# %%
# 爬取学校首页的深职要闻
import requests
from bs4 import BeautifulSoup
url = "https://www.szpt.edu.cn/"
r = requests.get(url)
r.encoding = r.apparent_encoding
soup = BeautifulSoup(r.text, "lxml")
div = soup.find("div", class_="list clearfix")
for item in div.find_all("a"):
    print(item.string)
# Out:
# 学校获评“学习强国”深圳学习平台先进单位荣誉称号
# 水贝珠宝集团董事长卢礼杭受聘为我校客座教授
# 我校七项作品获全省高校学生心理健康教育系列活...
# 学校召开党委理论学习中心组（扩大）学习会
# 我校举行“一站式”学生社区党群服务中心揭牌仪式
# 我校举行“书记、校长下午茶”活动

# %%
import requests
from bs4 import BeautifulSoup
url = "https://www.szpt.edu.cn/"
r = requests.get(url)
r.encoding = r.apparent_encoding
soup = BeautifulSoup(r.text, "lxml")
ul = soup.find("ul", class_ = "infoList")
for item in ul.find_all("a"):
    print(item.string)
# Out:
# [学习强国]点亮技能之光|深圳职业技术学院让梦想...
# [学习强国]【校园风采】省委书记李希、省长马兴...
# [宝安日报]传统工艺精品艺术展开幕
# [深圳新闻网]为“有备而老”培养新生力量 深职院...
# [羊城派]深职院：老年服务与管理专业开学
# [晶报APP]深职院举行“抗疫艺术作品展”，展现新...
# [深圳特区报]深职院首届老年服务与管理专业开学
# [深圳商报]深圳有了自己培养的“养老”专才
# [读特]深职院首届老年服务与管理专业开学啦！
# [晶报APP]老有颐养！深职院首届老年服务与管理专...

# %% [markdown]
# ## 豆瓣电影Top250数据爬取项目实战
# ### 项目分析
# - 获取网页-requests
# - 解析网页-beautifulsoup4
# - 数据存储-文本文件
# - 数据输出-格式化

# %% [markdown]
# ### 项目实现

# %%
# 导入相应的包
import requests
from bs4 import BeautifulSoup
import time
url = "https://movie.douban.com/top250?start="
head = {"User-Agent": "Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.135 Safari/537.36"}
html = ""
# 获取网页
for i in range(10):
    urli = url + str(i*25) + "&filter="
    r = requests.get(urli, headers=head)
    r.encoding = "utf8"
    html += r.text
    time.sleep(1)
print(html)
# Out:
# <!DOCTYPE html>
# <html lang="zh-CN" class="ua-windows ua-webkit">
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#     <meta name="renderer" content="webkit">
#     <meta name="referrer" content="always">
#     <meta name="google-site-verification" content="ok0wCgT20tBBgo9_zat2iAcimtN4Ftf5ccsh092Xeyw" />
#     <title>
# 豆瓣电影 Top 250
# </title>
#
#     <meta name="baidu-site-verification" content="cZdR4xxR7RxmM4zE" />
#     <meta http-equiv="Pragma" content="no-cache">
#     <meta http-equiv="Expires" content="Sun, 6 Mar 2005 01:00:00 GMT">
#
#     <link rel="apple-touch-icon" href="https://img3.doubanio.com/f/movie/d59b2715fdea4968a450ee5f6c95c7d7a2030065/pics/movie/apple-touch-icon.png">
#     <link href="https://img3.doubanio.com/f/shire/859dba5cddc7ed1435808cf5a8ddde5792cd6e0c/css/douban.css" rel="stylesheet" type="text/css">
#     <link href="https://img3.doubanio.com/f/shire/db02bd3a4c78de56425ddeedd748a6804af60ee9/css/separation/_all.css" rel="stylesheet" type="text/css">
#     <link href="https://img3.doubanio.com/f/movie/252bef058b97005c6a41e8f1b9f7b06b84bc71b3/css/movie/base/init.css" rel="stylesheet">
#     <script type="text/javascript">var _head_start = new Date();</script>
#     <script type="text/javascript" src="https://img3.doubanio.com/f/movie/0495cb173e298c28593766009c7b0a953246c5b5/js/movie/lib/jquery.js"></script>
#     <script type="text/javascript" src="https://img3.doubanio.com/f/shire/5ecaf46d6954d5a30bc7d99be86ae34031646e00/js/douban.js"></script>
#     <script type="text/javascript" src="https://img3.doubanio.com/f/shire/0efdc63b77f895eaf85281fb0e44d435c6239a3f/js/separation/_all.js"></script>
#
# <link href="https://img3.doubanio.com/f/movie/2c95f768ea74284b900c04c0209b0a44f0a0de52/css/movie/top_movies.css" rel="stylesheet" type="text/css" />
# <script type="text/javascript" src="https://img3.doubanio.com/f/shire/77323ae72a612bba8b65f845491513ff3329b1bb/js/do.js" data-cfg-autoload="false"></script>
# <script type='text/javascript'>
#     Do.ready(function(){
#             $("#mine-selector input[type='checkbox']").click(function(){
#                 var val = $(this).is(":checked")?$(this).val():"";
#                 window.location.href = '/top250?filter=' + val;
#             })
#     })
# </script>
#
#     <style type="text/css">
# .site-nav-logo img{margin-bottom:0;}
# </style>
#     <style type="text/css">img { max-width: 100%; }</style>
#     <script type="text/javascript"></script>
#     <link rel="stylesheet" href="https://img3.doubanio.com/misc/mixed_static/562925b5e3824700.css">
#
#     <link rel="shortcut icon" href="https://img3.doubanio.com/favicon.ico" type="image/x-icon">
# </head>
#
# <body>
#
#     <script type="text/javascript">var _body_start = new Date();</script>
#
#
#
#
#
#
#     <link href="//img3.doubanio.com/dae/accounts/resources/d3e2921/shire/bundle.css" rel="stylesheet" type="text/css">
#
#
#
# <div id="db-global-nav" class="global-nav">
#   <div class="bd">
#
# <div class="top-nav-info">
#   <a href="https://accounts.douban.com/passport/login?source=movie" class="nav-login" rel="nofollow">登录/注册</a>
# </div>
#
#
#     <div class="top-nav-doubanapp">
#   <a href="https://www.douban.com/doubanapp/app?channel=top-nav" class="lnk-doubanapp">下载豆瓣客户端</a>
#   <div id="doubanapp-tip">
#     <a href="https://www.douban.com/doubanapp/app?channel=qipao" class="tip-link">豆瓣 <span class="version">6.0</span> 全新发布</a>
#     <a href="javascript: void 0;" class="tip-close">×</a>
#   </div>
#   <div id="top-nav-appintro" class="more-items">
#     <p class="appintro-title">豆瓣</p>
#     <p class="qrcode">扫码直接下载</p>
#     <div class="download">
#       <a href="https://www.douban.com/doubanapp/redirect?channel=top-nav&direct_dl=1&download=iOS">iPhone</a>
#       <span>·</span>
#       <a href="https://www.douban.com/doubanapp/redirect?channel=top-nav&direct_dl=1&download=Android" class="download-android">Android</a>
#     </div>
#   </div>
# </div>
#
#
#
#
# <div class="global-nav-items">
#   <ul>
#     <li class="">
#       <a href="https://www.douban.com" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-main&quot;,&quot;uid&quot;:&quot;0&quot;}">豆瓣</a>
#     </li>
#     <li class="">
#       <a href="https://book.douban.com" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-book&quot;,&quot;uid&quot;:&quot;0&quot;}">读书</a>
#     </li>
#     <li class="on">
#       <a href="https://movie.douban.com"  data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-movie&quot;,&quot;uid&quot;:&quot;0&quot;}">电影</a>
#     </li>
#     <li class="">
#       <a href="https://music.douban.com" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-music&quot;,&quot;uid&quot;:&quot;0&quot;}">音乐</a>
#     </li>
#     <li class="">
#       <a href="https://www.douban.com/location" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-location&quot;,&quot;uid&quot;:&quot;0&quot;}">同城</a>
#     </li>
#     <li class="">
#       <a href="https://www.douban.com/group" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-group&quot;,&quot;uid&quot;:&quot;0&quot;}">小组</a>
#     </li>
#     <li class="">
#       <a href="https://read.douban.com&#47;?dcs=top-nav&amp;dcm=douban" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-read&quot;,&quot;uid&quot;:&quot;0&quot;}">阅读</a>
#     </li>
#     <li class="">
#       <a href="https://douban.fm&#47;?from_=shire_top_nav" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-fm&quot;,&quot;uid&quot;:&quot;0&quot;}">FM</a>
#     </li>
#     <li class="">
#       <a href="https://time.douban.com&#47;?dt_time_source=douban-web_top_nav" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-time&quot;,&quot;uid&quot;:&quot;0&quot;}">时间</a>
#     </li>
#     <li class="">
#       <a href="https://market.douban.com&#47;?utm_campaign=douban_top_nav&amp;utm_source=douban&amp;utm_medium=pc_web" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-market&quot;,&quot;uid&quot;:&quot;0&quot;}">豆品</a>
#     </li>
#   </ul>
# </div>
#
#   </div>
# </div>
# <script>
#   ;window._GLOBAL_NAV = {
#     DOUBAN_URL: "https://www.douban.com",
#     N_NEW_NOTIS: 0,
#     N_NEW_DOUMAIL: 0
#   };
# </script>
#
#
#
#     <script src="//img3.doubanio.com/dae/accounts/resources/d3e2921/shire/bundle.js" defer="defer"></script>
#
#
#
#
#
#
#
#
#     <link href="//img3.doubanio.com/dae/accounts/resources/d3e2921/movie/bundle.css" rel="stylesheet" type="text/css">
#
#
#
#
# <div id="db-nav-movie" class="nav">
#   <div class="nav-wrap">
#   <div class="nav-primary">
#     <div class="nav-logo">
#       <a href="https:&#47;&#47;movie.douban.com">豆瓣电影</a>
#     </div>
#     <div class="nav-search">
#       <form action="https:&#47;&#47;search.douban.com&#47;movie/subject_search" method="get">
#         <fieldset>
#           <legend>搜索：</legend>
#           <label for="inp-query">
#           </label>
#           <div class="inp"><input id="inp-query" name="search_text" size="22" maxlength="60" placeholder="搜索电影、电视剧、综艺、影人" value=""></div>
#           <div class="inp-btn"><input type="submit" value="搜索"></div>
#           <input type="hidden" name="cat" value="1002" />
#         </fieldset>
#       </form>
#     </div>
#   </div>
#   </div>
#   <div class="nav-secondary">
#
#
# <div class="nav-items">
#   <ul>
#     <li    ><a href="https://movie.douban.com/cinema/nowplaying/"
#      >影讯&购票</a>
#     </li>
#     <li    ><a href="https://movie.douban.com/explore"
#      >选电影</a>
#     </li>
#     <li    ><a href="https://movie.douban.com/tv/"
#      >电视剧</a>
#     </li>
#     <li    ><a href="https://movie.douban.com/chart"
#      >排行榜</a>
#     </li>
#     <li    ><a href="https://movie.douban.com/tag/"
#      >分类</a>
#     </li>
#     <li    ><a href="https://movie.douban.com/review/best/"
#      >影评</a>
#     </li>
#     <li    ><a href="https://movie.douban.com/annual/2020?source=navigation"
#      >2020年度榜单</a>
#     </li>
#     <li    ><a href="https://m.douban.com/standbyme/annual2019?source=navigation"
#             target="_blank"
#      >2019书影音报告</a>
#     </li>
#   </ul>
# </div>
#
#     <a href="https://movie.douban.com/annual/2020?source=movie_navigation" class="movieannual"></a>
#   </div>
# </div>
#
# <script id="suggResult" type="text/x-jquery-tmpl">
#   <li data-link="{{= url}}">
#             <a href="{{= url}}" onclick="moreurl(this, {from:'movie_search_sugg', query:'{{= keyword }}', subject_id:'{{= id}}', i: '{{= index}}', type: '{{= type}}'})">
#             <img src="{{= img}}" width="40" />
#             <p>
#                 <em>{{= title}}</em>
#                 {{if year}}
#                     <span>{{= year}}</span>
#                 {{/if}}
#                 {{if sub_title}}
#                     <br /><span>{{= sub_title}}</span>
#                 {{/if}}
#                 {{if address}}
#                     <br /><span>{{= address}}</span>
#                 {{/if}}
#                 {{if episode}}
#                     {{if episode=="unknow"}}
#                         <br /><span>集数未知</span>
#                     {{else}}
#                         <br /><span>共{{= episode}}集</span>
#                     {{/if}}
#                 {{/if}}
#             </p>
#         </a>
#         </li>
#   </script>
#
#
#
#
#     <script src="//img3.doubanio.com/dae/accounts/resources/d3e2921/movie/bundle.js" defer="defer"></script>
#
#
#
#
#
#
#     <div id="wrapper">
#
#
#
#     <div id="content">
#
#     <h1>豆瓣电影 Top 250</h1>
#
#         <div class="grid-16-8 clearfix">
#
#
#             <div class="article">
#
#
#
#
#
#
#
#
# <div class="opt mod">
#     <div class="tabs">
#
#
#
#     </div>
#     <span id="mine-selector">
#       <input type="checkbox"  value="unwatched">我没看过的
#     </span>
# </div>
#
#
#
# <ol class="grid_view">
#         <li>
#             <div class="item">
#                 <div class="pic">
#                     <em class="

#
#                     </div>
#                 </div>
#             </div>
#         </li>
# </ol>
#
#
#
#
#
#
#
#         <div class="paginator">
#         <span class="prev">
#             <link rel="prev" href="?start=200&amp;filter="/>
#             <a href="?start=200&amp;filter=" >&lt;前页</a>
#         </span>
#
#
#
#
#             <a href="?start=0&amp;filter=" >1</a>
#
#
#             <a href="?start=25&amp;filter=" >2</a>
#
#
#             <a href="?start=50&amp;filter=" >3</a>
#
#
#             <a href="?start=75&amp;filter=" >4</a>
#
#
#             <a href="?start=100&amp;filter=" >5</a>
#
#
#             <a href="?start=125&amp;filter=" >6</a>
#
#
#             <a href="?start=150&amp;filter=" >7</a>
#
#
#             <a href="?start=175&amp;filter=" >8</a>
#
#
#             <a href="?start=200&amp;filter=" >9</a>
#
#                 <span class="thispage">10</span>
#         <span class="next">
#             后页&gt;
#         </span>
#
#             <span class="count">(共250条)</span>
#         </div>
#
#
#
#             </div>
#             <div class="aside">
#
# <p class="pl">
#     豆瓣用户每天都在对“看过”的电影进行“很差”到“力荐”的评价，豆瓣根据每部影片看过的人数以及该影片所得的评价等综合数据，通过算法分析产生豆瓣电影 Top 250。
# </p>
#
# <div id="dale_movie_top250_bottom_right"></div>
#
# <!-- douban ad begin -->
#
#
#
#
#
#
# <div class="mobile-app-entrance block5 app-movie">
#     <a class="entrance-link" href="https://www.douban.com/doubanapp/frodo">
#         <div class="entrance-qrcode">
#             <img src="https://img3.doubanio.com/f/movie/a02f6ed325fc52e220f299d51e730c422e2bcd16/pics/movie/douban_app_ad/qrcode.png" alt="扫码下载豆瓣 App" width="80" height="80" />
#         </div>
#         <div class="entrance-info">
#             <span class="app-icon icon-movie"></span>
#             <span class="main-title">豆瓣</span>
#             <span class="sub-title">让好电影来找你</span>
#         </div>
#     </a>
# </div>
#
# <!-- douban ad end -->
#
#
#             </div>
#             <div class="extra">
#
#             </div>
#         </div>
#     </div>
#
#
#     <div id="footer">
#             <div class="footer-extra"></div>
#
# <span id="icp" class="fleft gray-link">
#     &copy; 2005－2020 douban.com, all rights reserved 北京豆网科技有限公司
# </span>
#
# <a href="https://www.douban.com/hnypt/variformcyst.py" style="display: none;"></a>
#
# <span class="fright">
#     <a href="https://www.douban.com/about">关于豆瓣</a>
#     · <a href="https://www.douban.com/jobs">在豆瓣工作</a>
#     · <a href="https://www.douban.com/about?topic=contactus">联系我们</a>
#     · <a href="https://www.douban.com/about/legal">法律声明</a>
#
#     · <a href="https://help.douban.com/?app=movie" target="_blank">帮助中心</a>
#     · <a href="https://www.douban.com/doubanapp/">移动应用</a>
#     · <a href="https://www.douban.com/partner/">豆瓣广告</a>
# </span>
#
#     </div>
#
#     </div>
#     <!-- COLLECTED JS -->
#
#
#     <link rel="stylesheet" type="text/css" href="https://img3.doubanio.com/f/shire/8377b9498330a2e6f056d863987cc7a37eb4d486/css/ui/dialog.css" />
#     <link rel="stylesheet" type="text/css" href="https://img3.doubanio.com/f/movie/4aca95d66d37ec0712b3d19973b5d8feb75f2f05/css/movie/mod/reg_login_pop.css" />
#     <script type="text/javascript" src="https://img3.doubanio.com/f/shire/77323ae72a612bba8b65f845491513ff3329b1bb/js/do.js" data-cfg-autoload="false"></script>
#     <script type="text/javascript" src="https://img3.doubanio.com/f/shire/383a6e43f2108dc69e3ff2681bc4dc6c72a5ffb0/js/ui/dialog.js"></script>
#     <script type="text/javascript">
#         var HTTPS_DB='https://www.douban.com';
# var account_pop={open:function(o,e){e?referrer="?referrer="+encodeURIComponent(e):referrer="?referrer="+window.location.href;var n="",i="",t=448;n="用户登录",i="https://accounts.douban.com/passport/login_popup?source=movie";var r=document.location.protocol+"//"+document.location.hostname,a=dui.Dialog({width:340,title:n,height:t,cls:"account_pop",isHideTitle:!0,modal:!0,content:"<iframe scrolling='no' frameborder='0' width='340' height='"+t+"' src='"+i+"' name='"+r+"'></iframe>"},!0),c=a.node;if(c.undelegate(),c.delegate(".dui-dialog-close","click",function(){var o=$("body");o.find("#login_msk").hide(),o.find(".account_pop").remove()}),$(window).width()<478){var d="";"reg"===o?d=HTTPS_DB+"/accounts/register"+referrer:"login"===o&&(d=HTTPS_DB+"/accounts/login"+referrer),window.location.href=d}else a.open();$(window).bind("message",function(o){"https://accounts.douban.com"===o.originalEvent.origin&&(c.find("iframe").css("height",o.originalEvent.data),c.height(o.originalEvent.data),a.update())})}};Douban&&Douban.init_show_login&&(Douban.init_show_login=function(o){var e=$(o);e.click(function(){var o=e.data("ref")||"";return account_pop.open("login",o),!1})}),Do(function(){$("body").delegate(".pop_register","click",function(o){o.preventDefault();var e=$(this).data("ref")||"";return account_pop.open("reg",e),!1}),$("body").delegate(".pop_login","click",function(o){o.preventDefault();var e=$(this).data("ref")||"";return account_pop.open("login",e),!1})});
#     </script>
#
#
#
#
#
#
#
#
# <script type="text/javascript">
#     (function (global) {
#         var newNode = global.document.createElement('script'),
#             existingNode = global.document.getElementsByTagName('script')[0],
#             adSource = '//erebor.douban.com/',
#             userId = '',
#             browserId = 'BJmKtS4KvMU',
#             criteria = '3:/top250?start=225&amp;filter=',
#             preview = '',
#             debug = false,
#             adSlots = ['dale_movie_top250_bottom_right'];
#
#         global.DoubanAdRequest = {src: adSource, uid: userId, bid: browserId, crtr: criteria, prv: preview, debug: debug};
#         global.DoubanAdSlots = (global.DoubanAdSlots || []).concat(adSlots);
#
#         newNode.setAttribute('type', 'text/javascript');
#         newNode.setAttribute('src', '//img1.doubanio.com/czF5ODV4Ni9mL2FkanMvMjBiYWY2MDg2ZWQ0MDE1YTNmMDJhNDYxMzhmNmM0MjQxYjExYWYwMC9hZC5yZWxlYXNlLmpz');
#         newNode.setAttribute('async', true);
#         existingNode.parentNode.insertBefore(newNode, existingNode);
#     })(this);
# </script>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript">
# var _paq = _paq || [];
# _paq.push(['trackPageView']);
# _paq.push(['enableLinkTracking']);
# (function() {
#     var p=(('https:' == document.location.protocol) ? 'https' : 'http'), u=p+'://fundin.douban.com/';
#     _paq.push(['setTrackerUrl', u+'piwik']);
#     _paq.push(['setSiteId', '100001']);
#     var d=document, g=d.createElement('script'), s=d.getElementsByTagName('script')[0];
#     g.type='text/javascript';
#     g.defer=true;
#     g.async=true;
#     g.src=p+'://img3.doubanio.com/dae/fundin/piwik.js';
#     s.parentNode.insertBefore(g,s);
# })();
# </script>
#
# <script type="text/javascript">
# var setMethodWithNs = function(namespace) {
#   var ns = namespace ? namespace + '.' : ''
#     , fn = function(string) {
#         if(!ns) {return string}
#         return ns + string
#       }
#   return fn
# }
#
# var gaWithNamespace = function(fn, namespace) {
#   var method = setMethodWithNs(namespace)
#   fn.call(this, method)
# }
#
# var _gaq = _gaq || []
#   , accounts = [
#       { id: 'UA-7019765-1', namespace: 'douban' }
#     , { id: 'UA-7019765-19', namespace: '' }
#     ]
#   , gaInit = function(account) {
#       gaWithNamespace(function(method) {
#         gaInitFn.call(this, method, account)
#       }, account.namespace)
#     }
#   , gaInitFn = function(method, account) {
#       _gaq.push([method('_setAccount'), account.id]);
#       _gaq.push([method('_setSampleRate'), '5']);
#
#
#   _gaq.push([method('_addOrganic'), 'google', 'q'])
#   _gaq.push([method('_addOrganic'), 'baidu', 'wd'])
#   _gaq.push([method('_addOrganic'), 'soso', 'w'])
#   _gaq.push([method('_addOrganic'), 'youdao', 'q'])
#   _gaq.push([method('_addOrganic'), 'so.360.cn', 'q'])
#   _gaq.push([method('_addOrganic'), 'sogou', 'query'])
#   if (account.namespace) {
#     _gaq.push([method('_addIgnoredOrganic'), '豆瓣'])
#     _gaq.push([method('_addIgnoredOrganic'), 'douban'])
#     _gaq.push([method('_addIgnoredOrganic'), '豆瓣网'])
#     _gaq.push([method('_addIgnoredOrganic'), 'www.douban.com'])
#   }
#
#       if (account.namespace === 'douban') {
#         _gaq.push([method('_setDomainName'), '.douban.com'])
#       }
#
#         _gaq.push([method('_setCustomVar'), 1, 'responsive_view_mode', 'desktop', 3])
#
#         _gaq.push([method('_setCustomVar'), 2, 'login_status', '0', 2]);
#
#       _gaq.push([method('_trackPageview')])
#     }
#
# for(var i = 0, l = accounts.length; i < l; i++) {
#   var account = accounts[i]
#   gaInit(account)
# }
#
#
# ;(function() {
#     var ga = document.createElement('script');
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     ga.setAttribute('async', 'true');
#     document.documentElement.firstChild.appendChild(ga);
# })()
# </script>
#
#
#
#
#
#
#
#
#
#
#     <!-- dae-web-movie--default-5d57d9f6dc-gq7dh-->
#
#   <script>_SPLITTEST=''</script>
# </body>
#
# </html>

# %%
with open("data/html.txt","w", encoding="utf8") as f:
    f.write(html)

# %%
with open("data/html.txt","r", encoding="utf8") as f:
    htxt = f.read()
print(htxt)
# Out:
# <!DOCTYPE html>
# <html lang="zh-CN" class="ua-windows ua-webkit">
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#     <meta name="renderer" content="webkit">
#     <meta name="referrer" content="always">
#     <meta name="google-site-verification" content="ok0wCgT20tBBgo9_zat2iAcimtN4Ftf5ccsh092Xeyw" />
#     <title>
# 豆瓣电影 Top 250
# </title>
#
#     <meta name="baidu-site-verification" content="cZdR4xxR7RxmM4zE" />
#     <meta http-equiv="Pragma" content="no-cache">
#     <meta http-equiv="Expires" content="Sun, 6 Mar 2005 01:00:00 GMT">
#
#     <link rel="apple-touch-icon" href="https://img3.doubanio.com/f/movie/d59b2715fdea4968a450ee5f6c95c7d7a2030065/pics/movie/apple-touch-icon.png">
#     <link href="https://img3.doubanio.com/f/shire/859dba5cddc7ed1435808cf5a8ddde5792cd6e0c/css/douban.css" rel="stylesheet" type="text/css">
#     <link href="https://img3.doubanio.com/f/shire/db02bd3a4c78de56425ddeedd748a6804af60ee9/css/separation/_all.css" rel="stylesheet" type="text/css">
#     <link href="https://img3.doubanio.com/f/movie/252bef058b97005c6a41e8f1b9f7b06b84bc71b3/css/movie/base/init.css" rel="stylesheet">
#     <script type="text/javascript">var _head_start = new Date();</script>
#     <script type="text/javascript" src="https://img3.doubanio.com/f/movie/0495cb173e298c28593766009c7b0a953246c5b5/js/movie/lib/jquery.js"></script>
#     <script type="text/javascript" src="https://img3.doubanio.com/f/shire/5ecaf46d6954d5a30bc7d99be86ae34031646e00/js/douban.js"></script>
#     <script type="text/javascript" src="https://img3.doubanio.com/f/shire/0efdc63b77f895eaf85281fb0e44d435c6239a3f/js/separation/_all.js"></script>
#
# <link href="https://img3.doubanio.com/f/movie/2c95f768ea74284b900c04c0209b0a44f0a0de52/css/movie/top_movies.css" rel="stylesheet" type="text/css" />
# <script type="text/javascript" src="https://img3.doubanio.com/f/shire/77323ae72a612bba8b65f845491513ff3329b1bb/js/do.js" data-cfg-autoload="false"></script>
# <script type='text/javascript'>
#     Do.ready(function(){
#             $("#mine-selector input[type='checkbox']").click(function(){
#                 var val = $(this).is(":checked")?$(this).val():"";
#                 window.location.href = '/top250?filter=' + val;
#             })
#     })
# </script>
#
#     <style type="text/css">
# .site-nav-logo img{margin-bottom:0;}
# </style>
#     <style type="text/css">img { max-width: 100%; }</style>
#     <script type="text/javascript"></script>
#     <link rel="stylesheet" href="https://img3.doubanio.com/misc/mixed_static/562925b5e3824700.css">
#
#     <link rel="shortcut icon" href="https://img3.doubanio.com/favicon.ico" type="image/x-icon">
# </head>
#
# <body>
#
#     <script type="text/javascript">var _body_start = new Date();</script>
#
#
#
#
#
#
#     <link href="//img3.doubanio.com/dae/accounts/resources/d3e2921/shire/bundle.css" rel="stylesheet" type="text/css">
#
#
#
# <div id="db-global-nav" class="global-nav">
#   <div class="bd">
#
# <div class="top-nav-info">
#   <a href="https://accounts.douban.com/passport/login?source=movie" class="nav-login" rel="nofollow">登录/注册</a>
# </div>
#
#
#     <div class="top-nav-doubanapp">
#   <a href="https://www.douban.com/doubanapp/app?channel=top-nav" class="lnk-doubanapp">下载豆瓣客户端</a>
#   <div id="doubanapp-tip">
#     <a href="https://www.douban.com/doubanapp/app?channel=qipao" class="tip-link">豆瓣 <span class="version">6.0</span> 全新发布</a>
#     <a href="javascript: void 0;" class="tip-close">×</a>
#   </div>
#   <div id="top-nav-appintro" class="more-items">
#     <p class="appintro-title">豆瓣</p>
#     <p class="qrcode">扫码直接下载</p>
#     <div class="download">
#       <a href="https://www.douban.com/doubanapp/redirect?channel=top-nav&direct_dl=1&download=iOS">iPhone</a>
#       <span>·</span>
#       <a href="https://www.douban.com/doubanapp/redirect?channel=top-nav&direct_dl=1&download=Android" class="download-android">Android</a>
#     </div>
#   </div>
# </div>
#
#
#
#
# <div class="global-nav-items">
#   <ul>
#     <li class="">
#       <a href="https://www.douban.com" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-main&quot;,&quot;uid&quot;:&quot;0&quot;}">豆瓣</a>
#     </li>
#     <li class="">
#       <a href="https://book.douban.com" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-book&quot;,&quot;uid&quot;:&quot;0&quot;}">读书</a>
#     </li>
#     <li class="on">
#       <a href="https://movie.douban.com"  data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-movie&quot;,&quot;uid&quot;:&quot;0&quot;}">电影</a>
#     </li>
#     <li class="">
#       <a href="https://music.douban.com" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-music&quot;,&quot;uid&quot;:&quot;0&quot;}">音乐</a>
#     </li>
#     <li class="">
#       <a href="https://www.douban.com/location" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-location&quot;,&quot;uid&quot;:&quot;0&quot;}">同城</a>
#     </li>
#     <li class="">
#       <a href="https://www.douban.com/group" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-group&quot;,&quot;uid&quot;:&quot;0&quot;}">小组</a>
#     </li>
#     <li class="">
#       <a href="https://read.douban.com&#47;?dcs=top-nav&amp;dcm=douban" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-read&quot;,&quot;uid&quot;:&quot;0&quot;}">阅读</a>
#     </li>
#     <li class="">
#       <a href="https://douban.fm&#47;?from_=shire_top_nav" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-fm&quot;,&quot;uid&quot;:&quot;0&quot;}">FM</a>
#     </li>
#     <li class="">
#       <a href="https://time.douban.com&#47;?dt_time_source=douban-web_top_nav" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-time&quot;,&quot;uid&quot;:&quot;0&quot;}">时间</a>
#     </li>
#     <li class="">
#       <a href="https://market.douban.com&#47;?utm_campaign=douban_top_nav&amp;utm_source=douban&amp;utm_medium=pc_web" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-market&quot;,&quot;uid&quot;:&quot;0&quot;}">豆品</a>
#     </li>
#   </ul>
# </div>
#
#   </div>
# </div>
# <script>
#   ;window._GLOBAL_NAV = {
#     DOUBAN_URL: "https://www.douban.com",
#     N_NEW_NOTIS: 0,
#     N_NEW_DOUMAIL: 0
#   };
# </script>
#
#
#
#     <script src="//img3.doubanio.com/dae/accounts/resources/d3e2921/shire/bundle.js" defer="defer"></script>
#
#
#
#
#
#
#
#
#     <link href="//img3.doubanio.com/dae/accounts/resources/d3e2921/movie/bundle.css" rel="stylesheet" type="text/css">
#
#
#
#
# <div id="db-nav-movie" class="nav">
#   <div class="nav-wrap">
#   <div class="nav-primary">
#     <div class="nav-logo">
#       <a href="https:&#47;&#47;movie.douban.com">豆瓣电影</a>
#     </div>
#     <div class="nav-search">
#       <form action="https:&#47;&#47;search.douban.com&#47;movie/subject_search" method="get">
#         <fieldset>
#           <legend>搜索：</legend>
#           <label for="inp-query">
#           </label>
#           <div class="inp"><input id="inp-query" name="search_text" size="22" maxlength="60" placeholder="搜索电影、电视剧、综艺、影人" value=""></div>
#           <div class="inp-btn"><input type="submit" value="搜索"></div>
#           <input type="hidden" name="cat" value="1002" />
#         </fieldset>
#       </form>
#     </div>
#   </div>
#   </div>
#   <div class="nav-secondary">
#
#
# <div class="nav-items">
#   <ul>
#     <li    ><a href="https://movie.douban.com/cinema/nowplaying/"
#      >影讯&购票</a>
#     </li>
#     <li    ><a href="https://movie.douban.com/explore"
#      >选电影</a>
#     </li>
#     <li    ><a href="https://movie.douban.com/tv/"
#      >电视剧</a>
#     </li>
#     <li    ><a href="https://movie.douban.com/chart"
#      >排行榜</a>
#     </li>
#     <li    ><a href="https://movie.douban.com/tag/"
#      >分类</a>
#     </li>
#     <li    ><a href="https://movie.douban.com/review/best/"
#      >影评</a>
#     </li>
#     <li    ><a href="https://movie.douban.com/annual/2020?source=navigation"
#      >2020年度榜单</a>
#     </li>
#     <li    ><a href="https://m.douban.com/standbyme/annual2019?source=navigation"
#             target="_blank"
#      >2019书影音报告</a>
#     </li>
#   </ul>
# </div>
#
#     <a href="https://movie.douban.com/annual/2020?source=movie_navigation" class="movieannual"></a>
#   </div>
# </div>
#
# <script id="suggResult" type="text/x-jquery-tmpl">
#   <li data-link="{{= url}}">
#             <a href="{{= url}}" onclick="moreurl(this, {from:'movie_search_sugg', query:'{{= keyword }}', subject_id:'{{= id}}', i: '{{= index}}', type: '{{= type}}'})">
#             <img src="{{= img}}" width="40" />
#             <p>
#                 <em>{{= title}}</em>
#                 {{if year}}
#                     <span>{{= year}}</span>
#                 {{/if}}
#                 {{if sub_title}}
#                     <br /><span>{{= sub_title}}</span>
#                 {{/if}}
#                 {{if address}}
#                     <br /><span>{{= address}}</span>
#                 {{/if}}
#                 {{if episode}}
#                     {{if episode=="unknow"}}
#                         <br /><span>集数未知</span>
#                     {{else}}
#                         <br /><span>共{{= episode}}集</span>
#                     {{/if}}
#                 {{/if}}
#             </p>
#         </a>
#         </li>
#   </script>
#
#
#
#
#     <script src="//img3.doubanio.com/dae/accounts/resources/d3e2921/movie/bundle.js" defer="defer"></script>
#
#
#
#
#
#
#     <div id="wrapper">
#
#
#
#     <div id="content">
#
#     <h1>豆瓣电影 Top 250</h1>
#
#         <div class="grid-16-8 clearfix">
#
#
#             <div class="article">
#
#
#
#
#
#
#
#
# <div class="opt mod">
#     <div class="tabs">
#
#
#
#     </div>
#     <span id="mine-selector">
#       <input type="checkbox"  value="unwatched">我没看过的
#     </span>
# </div>
#
#
#
# <ol class="grid_view">
#         <li>
#             <div class="item">
#                 <div class="pic">
#                     <em class="">1</em>
#                     <a href="https://movie.douban.com/subject/1292052/">
#                         <img width="100" alt="肖申克的救赎" src="https://img2.doubanio.com/view/photo/s_ratio_poster/public/p480747492.jpg" class="">
#                     </a>
#                 </div>
#                 <div class="info">
#                     <div class="hd">
#                         <a href="https://movie.douban.com/subject/1292052/" class="">
#                             <span class="title">肖申克的救赎</span>
#                                     <span class="title">&nbsp;/&nbsp;The Shawshank Redemption</span>
#                                 <span class="other">&nbsp;/&nbsp;月黑高飞(港)  /  刺激1995(台)</span>
#                         </a>
#
#
#                             <span class="playable">[可播放]</span>
#                     </div>
#                     <div class="bd">
#                         <p class="">
#                             导演: 弗兰克·德拉邦特 Frank Darabont&nbsp;&nbsp;&nbsp;主演: 蒂姆·罗宾斯 Tim Robbins /...<br>
#                             1994&nbsp;/&nbsp;美国&nbsp;/&nbsp;犯罪 剧情
#                         </p>
#
#
#                         <div class="star">
#                                 <span class="rating5-t"></span>
#                                 <span class="rating_num" property="v:average">9.7</span>
#                                 <span property="v:best" content="10.0"></span>
#                                 <span>2223449人评价</span>
#                         </div>
#
#                             <p class="quote">
#                                 <span class="inq">希望让人自由。</span>
#                             </p>
#                     </div>
#                 </div>
#             </div>
#         </li>
#         <li>
#             <div class="item">
#                 <div class="pic">
#                     <em class="">2</em>
#                     <a href="https://movie.douban.com/subject/1291546/">
#                         <img width="100" alt="霸王别姬" src="https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2561716440.jpg" class="">
#                     </a>
#                 </div>
#                 <div class="info">
#                     <div class="hd">
#                         <a href="https://movie.douban.com/subject/1291546/" class="">
#                             <span class="title">霸王别姬</span>
#                                 <span class="other">&nbsp;/&nbsp;再见，我的妾  /  Farewell My Concubine</span>
#                         </a>
#
#
#                             <span class="playable">[可播放]</span>
#                     </div>
#                     <div class="bd">
#                         <p class="">
#                             导演: 陈凯歌 Kaige Chen&nbsp;&nbsp;&nbsp;主演: 张国荣 Leslie Cheung / 张丰毅 Fengyi Zha...<br>
#                             1993&nbsp;/&nbsp;中国大陆 中国香港&nbsp;/&nbsp;剧情 爱情 同性
#                         </p>
#
#
#                         <div class="star">
#                                 <span class="rating5-t"></span>
#                                 <span class="rating_num" property="v:average">9.6</span>
#                                 <span property="v:best" content="10.0"></span>
#                                 <span>1650142人评价</span>
#                         </div>
#
#                             <p class="quote">
#                                 <span class="inq">风华绝代。</span>
#                             </p>
#                     </div>
#                 </div>
#             </div>
#         </li>
#         <li>
#             <div class="item">
#                 <div class="pic">
#                     <em class="">3</em>
#                     <a href="https://movie.douban.com/subject/1292720/">
#                         <img width="100" alt="阿甘正传" src="https://img2.doubanio.com/view/photo/s_ratio_poster/public/p2372307693.jpg" class="">
#                     </a>
#                 </div>
#                 <div class="info">
#                     <div class="hd">
#                         <a href="https://movie.douban.com/subject/1292720/" class="">
#                             <span class="title">阿甘正传</span>
#                                     <span class="title">&nbsp;/&nbsp;Forrest Gump</span>
#                                 <span class="other">&nbsp;/&nbsp;福雷斯特·冈普</span>
#                         </a>
#
#
#                             <span class="playable">[可播放]</span>
#                     </div>
#                     <div class="bd">
#                         <p class="">
#                             导演: 罗伯特·泽米吉斯 Robert Zemeckis&nbsp;&nbsp;&nbsp;主演: 汤姆·汉克斯 Tom Hanks / ...<br>
#                             1994&nbsp;/&nbsp;美国&nbsp;/&nbsp;剧情 爱情
#                         </p>
#
#
#                         <div class="star">
#                                 <span class="rating5-t"></span>
#                                 <span class="rating_num" property="v:average">9.5</span>
#                                 <span property="v:best" content="10.0"></span>
#                                 <span>1675111人评价</span>
#                         </div>
#
#                             <p class="quote">
#                                 <span class="inq">一部美国近现代史。</span>
#                             </p>
#                     </div>
#                 </div>
#             </div>
#         </li>
#         <li>
#             <div class="item">
#                 <div class="pic">
#                     <em class="">4</em>
#                     <a href="https://movie.douban.com/subject/1295644/">
#                         <img width="100" alt="这个杀手不太冷" src="https://img3.doubanio.com/view/photo/s_ratio_poster/public/p511118051.jpg" class="">
#                     </a>
#                 </div>
#                 <div class="info">
#                     <div class="hd">
#                         <a href="https://movie.douban.com/subject/1295644/" class="">
#                             <span class="title">这个杀手不太冷</span>
#                                     <span class="title">&nbsp;/&nbsp;Léon</span>
#                                 <span class="other">&nbsp;/&nbsp;杀手莱昂  /  终极追杀令(台)</span>
#                         </a>
#
#
#                     </div>
#                     <div class="bd">
#                         <p class="">
#                             导演: 吕克·贝松 Luc Besson&nbsp;&nbsp;&nbsp;主演: 让·雷诺 Jean Reno / 娜塔莉·波特曼 ...<br>
#                             1994&nbsp;/&nbsp;法国 美国&nbsp;/&nbsp;剧情 动作 犯罪
#                         </p>
#
#
#                         <div class="star">
#                                 <span class="rating45-t"></span>
#                                 <span class="rating_num" property="v:average">9.4</span>
#                                 <span property="v:best" content="10.0"></span>
#                                 <span>1859817人评价</span>
#                         </div>
#
#                             <p class="quote">
#                                 <span class="inq">怪蜀黍和小萝莉不得不说的故事。</span>
#                             </p>
#                     </div>
#                 </div>
#             </div>
#         </li>
#         <li>
#             <div class="item">
#                 <div class="pic">
#                     <em class="">5</em>
#                     <a href="https://movie.douban.com/subject/1292722/">
#                         <img width="100" alt="泰坦尼克号" src="https://img9.doubanio.com/view/photo/s_ratio_poster/public/p457760035.jpg" class="">
#                     </a>
#                 </div>
#                 <div class="info">
#                     <div class="hd">
#                         <a href="https://movie.douban.com/subject/1292722/" class="">
#                             <span class="title">泰坦尼克号</span>
#                                     <span class="title">&nbsp;/&nbsp;Titanic</span>
#                                 <span class="other">&nbsp;/&nbsp;铁达尼号(港 / 台)</span>
#                         </a>
#
#
#                             <span class="playable">[可播放]</span>
#                     </div>
#                     <div class="bd">
#                         <p class="">
#                             导演: 詹姆斯·卡梅隆 James Cameron&nbsp;&nbsp;&nbsp;主演: 莱昂纳多·迪卡普里奥 Leonardo...<br>
#                             1997&nbsp;/&nbsp;美国&nbsp;/&nbsp;剧情 爱情 灾难
#                         </p>
#
#
#                         <div class="star">
#                                 <span class="rating45-t"></span>
#                                 <span class="rating_num" property="v:average">9.4</span>
#                                 <span property="v:best" content="10.0"></span>
#                                 <span>1633264人评价</span>
#                         </div>
#
#                             <p class="quote">
#                                 <span class="inq

#
#                     </div>
#                 </div>
#             </div>
#         </li>
# </ol>
#
#
#
#
#
#
#
#         <div class="paginator">
#         <span class="prev">
#             <link rel="prev" href="?start=200&amp;filter="/>
#             <a href="?start=200&amp;filter=" >&lt;前页</a>
#         </span>
#
#
#
#
#             <a href="?start=0&amp;filter=" >1</a>
#
#
#             <a href="?start=25&amp;filter=" >2</a>
#
#
#             <a href="?start=50&amp;filter=" >3</a>
#
#
#             <a href="?start=75&amp;filter=" >4</a>
#
#
#             <a href="?start=100&amp;filter=" >5</a>
#
#
#             <a href="?start=125&amp;filter=" >6</a>
#
#
#             <a href="?start=150&amp;filter=" >7</a>
#
#
#             <a href="?start=175&amp;filter=" >8</a>
#
#
#             <a href="?start=200&amp;filter=" >9</a>
#
#                 <span class="thispage">10</span>
#         <span class="next">
#             后页&gt;
#         </span>
#
#             <span class="count">(共250条)</span>
#         </div>
#
#
#
#             </div>
#             <div class="aside">
#
# <p class="pl">
#     豆瓣用户每天都在对“看过”的电影进行“很差”到“力荐”的评价，豆瓣根据每部影片看过的人数以及该影片所得的评价等综合数据，通过算法分析产生豆瓣电影 Top 250。
# </p>
#
# <div id="dale_movie_top250_bottom_right"></div>
#
# <!-- douban ad begin -->
#
#
#
#
#
#
# <div class="mobile-app-entrance block5 app-movie">
#     <a class="entrance-link" href="https://www.douban.com/doubanapp/frodo">
#         <div class="entrance-qrcode">
#             <img src="https://img3.doubanio.com/f/movie/a02f6ed325fc52e220f299d51e730c422e2bcd16/pics/movie/douban_app_ad/qrcode.png" alt="扫码下载豆瓣 App" width="80" height="80" />
#         </div>
#         <div class="entrance-info">
#             <span class="app-icon icon-movie"></span>
#             <span class="main-title">豆瓣</span>
#             <span class="sub-title">让好电影来找你</span>
#         </div>
#     </a>
# </div>
#
# <!-- douban ad end -->
#
#
#             </div>
#             <div class="extra">
#
#             </div>
#         </div>
#     </div>
#
#
#     <div id="footer">
#             <div class="footer-extra"></div>
#
# <span id="icp" class="fleft gray-link">
#     &copy; 2005－2020 douban.com, all rights reserved 北京豆网科技有限公司
# </span>
#
# <a href="https://www.douban.com/hnypt/variformcyst.py" style="display: none;"></a>
#
# <span class="fright">
#     <a href="https://www.douban.com/about">关于豆瓣</a>
#     · <a href="https://www.douban.com/jobs">在豆瓣工作</a>
#     · <a href="https://www.douban.com/about?topic=contactus">联系我们</a>
#     · <a href="https://www.douban.com/about/legal">法律声明</a>
#
#     · <a href="https://help.douban.com/?app=movie" target="_blank">帮助中心</a>
#     · <a href="https://www.douban.com/doubanapp/">移动应用</a>
#     · <a href="https://www.douban.com/partner/">豆瓣广告</a>
# </span>
#
#     </div>
#
#     </div>
#     <!-- COLLECTED JS -->
#
#
#     <link rel="stylesheet" type="text/css" href="https://img3.doubanio.com/f/shire/8377b9498330a2e6f056d863987cc7a37eb4d486/css/ui/dialog.css" />
#     <link rel="stylesheet" type="text/css" href="https://img3.doubanio.com/f/movie/4aca95d66d37ec0712b3d19973b5d8feb75f2f05/css/movie/mod/reg_login_pop.css" />
#     <script type="text/javascript" src="https://img3.doubanio.com/f/shire/77323ae72a612bba8b65f845491513ff3329b1bb/js/do.js" data-cfg-autoload="false"></script>
#     <script type="text/javascript" src="https://img3.doubanio.com/f/shire/383a6e43f2108dc69e3ff2681bc4dc6c72a5ffb0/js/ui/dialog.js"></script>
#     <script type="text/javascript">
#         var HTTPS_DB='https://www.douban.com';
# var account_pop={open:function(o,e){e?referrer="?referrer="+encodeURIComponent(e):referrer="?referrer="+window.location.href;var n="",i="",t=448;n="用户登录",i="https://accounts.douban.com/passport/login_popup?source=movie";var r=document.location.protocol+"//"+document.location.hostname,a=dui.Dialog({width:340,title:n,height:t,cls:"account_pop",isHideTitle:!0,modal:!0,content:"<iframe scrolling='no' frameborder='0' width='340' height='"+t+"' src='"+i+"' name='"+r+"'></iframe>"},!0),c=a.node;if(c.undelegate(),c.delegate(".dui-dialog-close","click",function(){var o=$("body");o.find("#login_msk").hide(),o.find(".account_pop").remove()}),$(window).width()<478){var d="";"reg"===o?d=HTTPS_DB+"/accounts/register"+referrer:"login"===o&&(d=HTTPS_DB+"/accounts/login"+referrer),window.location.href=d}else a.open();$(window).bind("message",function(o){"https://accounts.douban.com"===o.originalEvent.origin&&(c.find("iframe").css("height",o.originalEvent.data),c.height(o.originalEvent.data),a.update())})}};Douban&&Douban.init_show_login&&(Douban.init_show_login=function(o){var e=$(o);e.click(function(){var o=e.data("ref")||"";return account_pop.open("login",o),!1})}),Do(function(){$("body").delegate(".pop_register","click",function(o){o.preventDefault();var e=$(this).data("ref")||"";return account_pop.open("reg",e),!1}),$("body").delegate(".pop_login","click",function(o){o.preventDefault();var e=$(this).data("ref")||"";return account_pop.open("login",e),!1})});
#     </script>
#
#
#
#
#
#
#
#
# <script type="text/javascript">
#     (function (global) {
#         var newNode = global.document.createElement('script'),
#             existingNode = global.document.getElementsByTagName('script')[0],
#             adSource = '//erebor.douban.com/',
#             userId = '',
#             browserId = 'BJmKtS4KvMU',
#             criteria = '3:/top250?start=225&amp;filter=',
#             preview = '',
#             debug = false,
#             adSlots = ['dale_movie_top250_bottom_right'];
#
#         global.DoubanAdRequest = {src: adSource, uid: userId, bid: browserId, crtr: criteria, prv: preview, debug: debug};
#         global.DoubanAdSlots = (global.DoubanAdSlots || []).concat(adSlots);
#
#         newNode.setAttribute('type', 'text/javascript');
#         newNode.setAttribute('src', '//img1.doubanio.com/czF5ODV4Ni9mL2FkanMvMjBiYWY2MDg2ZWQ0MDE1YTNmMDJhNDYxMzhmNmM0MjQxYjExYWYwMC9hZC5yZWxlYXNlLmpz');
#         newNode.setAttribute('async', true);
#         existingNode.parentNode.insertBefore(newNode, existingNode);
#     })(this);
# </script>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript">
# var _paq = _paq || [];
# _paq.push(['trackPageView']);
# _paq.push(['enableLinkTracking']);
# (function() {
#     var p=(('https:' == document.location.protocol) ? 'https' : 'http'), u=p+'://fundin.douban.com/';
#     _paq.push(['setTrackerUrl', u+'piwik']);
#     _paq.push(['setSiteId', '100001']);
#     var d=document, g=d.createElement('script'), s=d.getElementsByTagName('script')[0];
#     g.type='text/javascript';
#     g.defer=true;
#     g.async=true;
#     g.src=p+'://img3.doubanio.com/dae/fundin/piwik.js';
#     s.parentNode.insertBefore(g,s);
# })();
# </script>
#
# <script type="text/javascript">
# var setMethodWithNs = function(namespace) {
#   var ns = namespace ? namespace + '.' : ''
#     , fn = function(string) {
#         if(!ns) {return string}
#         return ns + string
#       }
#   return fn
# }
#
# var gaWithNamespace = function(fn, namespace) {
#   var method = setMethodWithNs(namespace)
#   fn.call(this, method)
# }
#
# var _gaq = _gaq || []
#   , accounts = [
#       { id: 'UA-7019765-1', namespace: 'douban' }
#     , { id: 'UA-7019765-19', namespace: '' }
#     ]
#   , gaInit = function(account) {
#       gaWithNamespace(function(method) {
#         gaInitFn.call(this, method, account)
#       }, account.namespace)
#     }
#   , gaInitFn = function(method, account) {
#       _gaq.push([method('_setAccount'), account.id]);
#       _gaq.push([method('_setSampleRate'), '5']);
#
#
#   _gaq.push([method('_addOrganic'), 'google', 'q'])
#   _gaq.push([method('_addOrganic'), 'baidu', 'wd'])
#   _gaq.push([method('_addOrganic'), 'soso', 'w'])
#   _gaq.push([method('_addOrganic'), 'youdao', 'q'])
#   _gaq.push([method('_addOrganic'), 'so.360.cn', 'q'])
#   _gaq.push([method('_addOrganic'), 'sogou', 'query'])
#   if (account.namespace) {
#     _gaq.push([method('_addIgnoredOrganic'), '豆瓣'])
#     _gaq.push([method('_addIgnoredOrganic'), 'douban'])
#     _gaq.push([method('_addIgnoredOrganic'), '豆瓣网'])
#     _gaq.push([method('_addIgnoredOrganic'), 'www.douban.com'])
#   }
#
#       if (account.namespace === 'douban') {
#         _gaq.push([method('_setDomainName'), '.douban.com'])
#       }
#
#         _gaq.push([method('_setCustomVar'), 1, 'responsive_view_mode', 'desktop', 3])
#
#         _gaq.push([method('_setCustomVar'), 2, 'login_status', '0', 2]);
#
#       _gaq.push([method('_trackPageview')])
#     }
#
# for(var i = 0, l = accounts.length; i < l; i++) {
#   var account = accounts[i]
#   gaInit(account)
# }
#
#
# ;(function() {
#     var ga = document.createElement('script');
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     ga.setAttribute('async', 'true');
#     document.documentElement.firstChild.appendChild(ga);
# })()
# </script>
#
#
#
#
#
#
#
#
#
#
#     <!-- dae-web-movie--default-5d57d9f6dc-gq7dh-->
#
#   <script>_SPLITTEST=''</script>
# </body>
#
# </html>

# %%
# 数据解析
from pprint import pprint
soup = BeautifulSoup(html, "html.parser")
items = soup.find_all("div", class_="info")
movies = []
for item in items:
    # 爬取电影名称
    t = item.find("span", class_="title").get_text()
    # 评分
    r = item.find("span", class_="rating_num").get_text()
    # 评价人数
    p = item.find("div", class_="star").find_all("span")[-1].get_text()[:-3]
# 数据存储
    movies.append([t,r,p])
# 数据格式化输出
pprint(movies)
# Out:
# [['肖申克的救赎', '9.7', '2223449'],
#  ['霸王别姬', '9.6', '1650142'],
#  ['阿甘正传', '9.5', '1675111'],
#  ['这个杀手不太冷', '9.4', '1859817'],
#  ['泰坦尼克号', '9.4', '1633264'],
#  ['美丽人生', '9.5', '1036303'],
#  ['千与千寻', '9.4', '1748323'],
#  ['辛德勒的名单', '9.5', '854759'],
#  ['盗梦空间', '9.3', '1627122'],
#  ['忠犬八公的故事', '9.4', '1112237'],
#  ['星际穿越', '9.3', '1298755'],
#  ['海上钢琴师', '9.3', '1324793'],
#  ['楚门的世界', '9.3', '1211382'],
#  ['三傻大闹宝莱坞', '9.2', '1482067'],
#  ['机器人总动员', '9.3', '1045074'],
#  ['放牛班的春天', '9.3', '1028342'],
#  ['大话西游之大圣娶亲', '9.2', '1188402'],
#  ['熔炉', '9.3', '727267'],
#  ['疯狂动物城', '9.2', '1433618'],
#  ['无间道', '9.2', '977267'],
#  ['教父', '9.3', '726419'],
#  ['龙猫', '9.2', '991729'],
#  ['当幸福来敲门', '9.1', '1192678'],
#  ['怦然心动', '9.1', '1394478'],
#  ['触不可及', '9.2', '772678'],
#  ['控方证人', '9.6', '331620'],
#  ['蝙蝠侠：黑暗骑士', '9.2', '809135'],
#  ['活着', '9.3', '628762'],
#  ['末代皇帝', '9.3', '601906'],
#  ['寻梦环游记', '9.1', '1207717'],
#  ['乱世佳人', '9.3', '533883'],
#  ['何以为家', '9.1', '763401'],
#  ['指环王3：王者无敌', '9.2', '588683'],
#  ['摔跤吧！爸爸', '9.0', '1223727'],
#  ['飞屋环游记', '9.0', '1037221'],
#  ['哈利·波特与魔法石', '9.1', '805136'],
#  ['少年派的奇幻漂流', '9.1', '1097536'],
#  ['素媛', '9.3', '501935'],
#  ['十二怒汉', '9.4', '356750'],
#  ['哈尔的移动城堡', '9.1', '765868'],
#  ['鬼子来了', '9.3', '479590'],
#  ['天空之城', '9.1', '653864'],
#  ['大话西游之月光宝盒', '9.0', '946712'],
#  ['我不是药神', '9.0', '1628195'],
#  ['闻香识女人', '9.1', '662263'],
#  ['罗马假日', '9.0', '755934'],
#  ['天堂电影院', '9.2', '503396'],
#  ['辩护人', '9.2', '473974'],
#  ['搏击俱乐部', '9.0', '672631'],
#  ['猫鼠游戏', '9.0', '661665'],
#  ['大闹天宫', '9.4', '313106'],
#  ['教父2', '9.2', '405899'],
#  ['狮子王', '9.0', '635093'],
#  ['指环王2：双塔奇兵', '9.1', '536741'],
#  ['死亡诗社', '9.1', '538055'],
#  ['钢琴家', '9.2', '417012'],
#  ['黑客帝国', '9.0', '614291'],
#  ['指环王1：魔戒再现', '9.0', '602754'],
#  ['窃听风暴', '9.1', '438832'],
#  ['饮食男女', '9.1', '449072'],
#  ['美丽心灵', '9.0', '586865'],
#  ['两杆大烟枪', '9.1', '472288'],
#  ['让子弹飞', '8.8', '1251334'],
#  ['绿皮书', '8.9', '1196531'],
#  ['本杰明·巴顿奇事', '8.9', '762256'],
#  ['飞越疯人院', '9.1', '455981'],
#  ['海蒂和爷爷', '9.2', '330932'],
#  ['看不见的客人', '8.8', '923890'],
#  ['西西里的美丽传说', '8.9', '756798'],
#  ['拯救大兵瑞恩', '9.0', '500713'],
#  ['小鞋子', '9.2', '313144'],
#  ['穿条纹睡衣的男孩', '9.1', '390450'],
#  ['情书', '8.9', '699551'],
#  ['音乐之声', '9.0', '462168'],
#  ['海豚湾', '9.3', '299530'],
#  ['美国往事', '9.2', '323883'],
#  ['致命魔术', '8.9', '667148'],
#  ['沉默的羔羊', '8.9', '657230'],
#  ['低俗小说', '8.9', '643884'],
#  ['禁闭岛', '8.8', '730124'],
#  ['蝴蝶效应', '8.8', '722354'],
#  ['七宗罪', '8.8', '754239'],
#  ['心灵捕手', '8.9', '542906'],
#  ['布达佩斯大饭店', '8.9', '686045'],
#  ['春光乍泄', '8.9', '484493'],
#  ['被嫌弃的松子的一生', '8.9', '574276'],
#  ['摩登时代', '9.3', '220587'],
#  ['阿凡达', '8.7', '1019880'],
#  ['哈利·波特与死亡圣器(下)', '8.9', '595302'],
#  ['喜剧之王', '8.8', '735526'],
#  ['剪刀手爱德华', '8.7', '858623'],
#  ['致命ID', '8.8', '616242'],
#  ['勇敢的心', '8.9', '470999'],
#  ['加勒比海盗', '8.8', '680784'],
#  ['杀人回忆', '8.9', '519858'],
#  ['狩猎', '9.1', '284306'],
#  ['天使爱美丽', '8.7', '814797'],
#  ['请以你的名字呼唤我', '8.9', '510198'],
#  ['断背山', '8.8', '571570'],
#  ['7号房的礼物', '8.9', '414962'],
#  ['红辣椒', '9.0', '320082'],
#  ['幽灵公主', '8.9', '421138'],
#  ['小森林 夏秋篇', '9.0', '327311'],
#  ['阳光灿烂的日子', '8.8', '485762'],
#  ['第六感', '8.9', '425247'],
#  ['重庆森林', '8.7', '614978'],
#  ['入殓师', '8.9', '467771'],
#  ['小森林 冬春篇', '9.0', '291964'],
#  ['唐伯虎点秋香', '8.6', '804621'],
#  ['爱在黎明破晓前', '8.8', '471078'],
#  ['消失的爱人', '8.7', '696397'],
#  ['一一', '9.0', '275541'],
#  ['超脱', '8.9', '366319'],
#  ['蝙蝠侠：黑暗骑士崛起', '8.8', '556559'],
#  ['菊次郎的夏天', '8.8', '434728'],
#  ['侧耳倾听', '8.9', '357001'],
#  ['倩女幽魂', '8.7', '565988'],
#  ['无人知晓', '9.1', '219443'],
#  ['超能陆战队', '8.7', '775553'],
#  ['功夫', '8.6', '764651'],
#  ['萤火之森', '8.9', '392995'],
#  ['甜蜜蜜', '8.8', '403021'],
#  ['借东西的小人阿莉埃蒂', '8.8', '422246'],
#  ['玛丽和马克思', '8.9', '351504'],
#  ['人生果实', '9.5', '118408'],
#  ['驯龙高手', '8.7', '593572'],
#  ['爱在日落黄昏时', '8.8', '395334'],
#  ['告白', '8.7', '563286'],
#  ['大鱼', '8.8', '450636'],
#  ['幸福终点站', '8.8', '422532'],
#  ['阳光姐妹淘', '8.8', '485784'],
#  ['完美的世界', '9.1', '208558'],
#  ['射雕英雄传之东成西就', '8.7', '505225'],
#  ['恐怖直播', '8.8', '499283'],
#  ['哈利·波特与阿兹卡班的囚徒', '8.8', '463305'],
#  ['天书奇谭', '9.2', '172925'],
#  ['怪兽电力公司', '8.7', '504009'],
#  ['神偷奶爸', '8.6', '758761'],
#  ['玩具总动员3', '8.8', '390345'],
#  ['傲慢与偏见', '8.6', '599685'],
#  ['时空恋旅人', '8.8', '439038'],
#  ['教父3', '8.9', '270648'],
#  ['血战钢锯岭', '8.7', '625287'],
#  ['釜山行', '8.5', '900036'],
#  ['哈利·波特与密室', '8.7', '485781'],
#  ['哪吒闹海', '9.1', '193597'],
#  ['被解救的姜戈', '8.7', '469589'],
#  ['风之谷', '8.9', '295718'],
#  ['喜宴', '8.9', '262223'],
#  ['七武士', '9.3', '147074'],
#  ['电锯惊魂', '8.7', '396432'],
#  ['一个叫欧维的男人决定去死', '8.9', '310874'],
#  ['我是山姆', '8.9', '239846'],
#  ['英雄本色', '8.7', '396456'],
#  ['上帝之城', '9.0', '243197'],
#  ['头号玩家', '8.6', '1088414'],
#  ['谍影重重3', '8.8', '333323'],
#  ['疯狂原始人', '8.7', '672827'],
#  ['岁月神偷', '8.7', '483847'],
#  ['纵横四海', '8.8', '316180'],
#  ['卢旺达饭店', '8.9', '235833'],
#  ['三块广告牌', '8.7', '647647'],
#  ['未麻的部屋', '9.0', '216242'],
#  ['达拉斯买家俱乐部', '8.8', '349933'],
#  ['花样年华', '8.7', '446246'],
#  ['心迷宫', '8.7', '383044'],
#  ['记忆碎片', '8.6', '482902'],
#  ['模仿游戏', '8.7', '473776'],
#  ['黑客帝国3：矩阵革命', '8.8', '329409'],
#  ['你的名字。', '8.4', '1072719'],
#  ['新世界', '8.8', '271949'],
#  ['荒蛮故事', '8.8', '329147'],
#  ['真爱至上', '8.6', '566760'],
#  ['忠犬八公物语', '9.2', '145630'],
#  ['爆裂鼓手', '8.7', '436519'],
#  ['萤火虫之墓', '8.7', '339067'],
#  ['贫民窟的百万富翁', '8.6', '601946'],
#  ['东邪西毒', '8.6', '465404'],
#  ['头脑特工队', '8.7', '451599'],
#  ['黑天鹅', '8.6', '665038'],
#  ['海街日记', '8.8', '314695'],
#  ['惊魂记', '9.0', '189928'],
#  ['你看起来好像很好吃', '8.9', '265082'],
#  ['无敌破坏王', '8.7', '413018'],
#  ['冰川时代', '8.6', '490391'],
#  ['雨人', '8.7', '326724'],
#  ['恋恋笔记本', '8.5', '513736'],
#  ['小偷家族', '8.7', '642058'],
#  ['绿里奇迹', '8.9', '226821'],
#  ['爱在午夜降临前', '8.8', '262916'],
#  ['疯狂的石头', '8.5', '624770'],
#  ['恐怖游轮', '8.5', '617286'],
#  ['二十二', '8.7', '229910'],
#  ['奇迹男孩', '8.6', '448258'],
#  ['雨中曲', '9.0', '160805'],
#  ['魔女宅急便', '8.6', '359536'],
#  ['海边的曼彻斯特', '8.6', '377644'],
#  ['房间', '8.8', '308390'],
#  ['虎口脱险', '8.9', '184446'],
#  ['哈利·波特与火焰杯', '8.6', '416738'],
#  ['人工智能', '8.7', '342420'],
#  ['罗生门', '8.8', '237632'],
#  ['可可西里', '8.8', '229978'],
#  ['终结者2：审判日', '8.7', '273042'],
#  ['2001太空漫游', '8.8', '224472'],
#  ['初恋这件小事', '8.4', '810150'],
#  ['城市之光', '9.3', '101681'],
#  ['色，戒', '8.5', '539108'],
#  ['九品芝麻官', '8.5', '447500'],
#  ['寄生虫', '8.7', '1058451'],
#  ['魂断蓝桥', '8.8', '216376'],
#  ['牯岭街少年杀人事件', '8.8', '201653'],
#  ['遗愿清单', '8.7', '302912'],
#  ['海洋', '9.1', '135604'],
#  ['新龙门客栈', '8.6', '344152'],
#  ['大佛普拉斯', '8.7', '308858'],
#  ['燃情岁月', '8.8', '229587'],
#  ['源代码', '8.5', '646033'],
#  ['青蛇', '8.6', '400005'],
#  ['无耻混蛋', '8.6', '375171'],
#  ['波西米亚狂想曲', '8.7', '448390'],
#  ['穿越时空的少女', '8.6', '312991'],
#  ['血钻', '8.7', '281361'],
#  ['疯狂的麦克斯4：狂暴之路', '8.6', '403197'],
#  ['步履不停', '8.8', '202947'],
#  ['阿飞正传', '8.5', '387733'],
#  ['谍影重重2', '8.7', '279941'],
#  ['完美陌生人', '8.5', '430106'],
#  ['地球上的星星', '8.9', '163068'],
#  ['战争之王', '8.7', '278303'],
#  ['彗星来的那一夜', '8.5', '400051'],
#  ['香水', '8.5', '446561'],
#  ['谍影重重', '8.6', '334341'],
#  ['朗读者', '8.6', '385953'],
#  ['东京物语', '9.2', '101373'],
#  ['猜火车', '8.5', '352571'],
#  ['再次出发之纽约遇见你', '8.6', '330827'],
#  ['千钧一发', '8.8', '198406'],
#  ['浪潮', '8.7', '216645'],
#  ['驴得水', '8.3', '720180'],
#  ['聚焦', '8.8', '223563'],
#  ['黑客帝国2：重装上阵', '8.6', '288774'],
#  ['我爱你', '9.0', '123157'],
#  ['小萝莉的猴神大叔', '8.4', '388614'],
#  ['追随', '8.9', '144437'],
#  ['东京教父', '9.0', '129279'],
#  ['无间道2', '8.6', '311308'],
#  ['黑鹰坠落', '8.7', '229913'],
#  ['一次别离', '8.7', '209477'],
#  ['网络谜踪', '8.6', '412319']]

# %%
with open("data/movies.csv", "w", encoding="gbk") as f:
    f.write("电影名称,评分,评价人数\n")
    for m in movies:
        f.write(",".join(m) + "\n")

# %%
from lxml import etree

# %%
//*[@id="content"]/div/div[1]/ol/li[1]/div/div[2]/div[1]/a/span[1]
//*[@id="content"]/div/div[1]/ol/li[2]/div/div[2]/div[1]/a/span[1]
//*[@id="content"]/div/div[1]/ol/li[3]/div/div[2]/div[1]/a/span[1]

//*[@id="content"]/div/div[1]/ol/li[*]/div/div[2]/div[1]/a/span[1]

# %% [markdown]
# ## 总结与提高

# %%
# 正则表达式

# %%
# requests库的参数

# %%
# 网页内容的分页处理

# %% [markdown]
# ## 巩固与应用

# %%
# 中国大学排名爬虫

# %%
# 天气预报爬虫

# %%
# 豆瓣读书新书快递爬虫

# %%
import csv
import requests
from bs4 import BeautifulSoup
header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36'}
r = requests.get("https://book.douban.com/latest?icn=index-latestbook-al",headers=header)
soup = BeautifulSoup(r.text,"lxml")
names = []
scores = []
authors = []
comps = []
dates = []
for res in soup.find_all("div",class_="detail-frame"):
    names.append(res.h2.a.string)
    score = res.p.find("span",class_="font-small color-lightgray").string.replace("\n","")
    if score.strip()=="":
        score = "未知"
    scores.append(score.strip())
    strs = res.find("p",class_="color-gray").string.split("/")
    authors.append(strs[0].strip())
    comps.append(strs[1].strip())
    dates.append(strs[2].strip())
results = [list(i) for i in zip(names,scores,authors,comps,dates)]
print(results)
# for line in results:
#     print(",".join(line))
with open("data/douban_books.csv","w",errors ='ignore',newline ='') as fp: 
    fp.write("作者,评分,作者,出版社,出版日期\n")
    #csv.writer(fp).writerows(list(results))
    for line in results:
        fp.write(",".join(line)+"\n")
    #fp.close()
#print(scores)
# Out:
# [['喷火器', '评价人数不足', '[阿根廷] 罗伯特·阿尔特', '四川文艺出版社', '2021-1'], ['彩虹几度', '评价人数不足', '[日] 川端康成', '上海译文出版社', '2020-11'], ['恶土', '评价人数不足', '[美] 安妮·普鲁', '人民文学出版社', '2020-11'], ['乘战车的人', '评价人数不足', '[澳] 帕特里克·怀特', '浙江文艺出版社', '2021-1'], ['查泰莱夫人的情人', '未知', '(英国)  D.H.劳伦斯', '译林出版社', '2021-1'], ['我的朋友阿波罗', '7.5', '[美] 西格丽德·努涅斯', '上海译文出版社', '2020-11'], ['活在鱼缸里的她', '未知', '（英国）苏•哈伯德', '译林出版社', '2020-11'], ['沉默的病人', '未知', '[英]亚历克斯·麦克利兹', '河南文艺出版社', '2020-12-6'], ['藏狐砂冈先生', '未知', '（日）Q桑', '四川美术出版社', '2020-12-1'], ['熟年', '评价人数不足', '伊北', '中信出版集团·文艺社', '2021-1-1'], ['六十个故事', '未知', '[意] 迪诺·布扎蒂', '宝琴文化|北京联合出版公司', '2020-11-1'], ['战后风景', '评价人数不足', '[比] 菲利普·德·皮埃尔庞 编', '埃里克·朗贝 绘', '后浪丨上海文化出版社'], ['梦之囚徒：降维', '未知', '[法] 马克-安托万·马修', '后浪 | 上海文化出版社', '2020-12'], ['失落世界狂想曲', '评价人数不足', '[法] 尼古拉·德克雷西', '后浪丨湖南美术出版社', '2020-12'], ['诱惑者日记', '评价人数不足', '［丹麦］索伦•克尔凯郭尔', '外语教学与研究出版社', '2020-12'], ['致命尖端', '未知', '[美] 托马斯·品钦', '译林出版社', '2020-11'], ['火神被杀', '未知', '[日] 松本清张', '江苏凤凰文艺出版社', '2020-12'], ['伊藤润二短篇精选集', '未知', '[日] 伊藤润二', '新星出版社', '2020-12'], ['喀耳刻', '评价人数不足', '[美]马德琳·米勒（Madeline Miller）', '中信出版集团', '2021-1'], ['热带', '未知', '[日] 森见登美彦', '山东画报出版社', '2020-12'], ['可是我偏偏不喜欢', '8.5', '吴晓乐', '中国友谊出版公司', '2020-11-12'], ['珠崖', '评价人数不足', '[美] 薛爱华', '后浪×楚尘文化丨九州出版社', '2020-12'], ['铁壁之围', '评价人数不足', '[英] 亚历山大·沃森', '后浪丨九州出版社', '2020-12'], ['传染', '9.0', '[英] 亚当·库哈尔斯基', '中信出版集团', '2020-11'], ['一把海贝', '未知', '[英]托比·格林', '社会科学文献出版社', '2020-12'], ['职场妈妈生存报告', '8.2', '(美)凯特琳·柯林斯 (Caitlyn Collins)', '上海人民出版社', '世纪文景'], ['钱钟书的学术人生', '8.6', '王水照', '中华书局', '2020-11'], ['钱锺书选唐诗', '未知', '钱锺书 选', '杨绛 抄', '人民文学出版社编辑部 整理'], ['辨色视朝', '评价人数不足', '李文杰', '上海人民出版社', '2020-11'], ['一堆谎言', '评价人数不足', '[意] 米开朗基罗·安东尼奥尼', '后浪丨四川文艺出版社', '2021-1'], ['刑罚的历史', '未知', '罗翔', '云南人民出版社', '2020-12'], ['阿拉·古勒的伊斯坦布尔', '未知', '[土耳其] 阿拉·古勒 摄影  [土耳其]奥尔罕·帕慕克 序', '世纪文景|上海人民出版社', '2020-11-30'], ['我的姑姑三毛', '未知', '陈天慈', '上海文艺出版社', '2020-12'], ['尖叫的经典', '未知', '张长晓', '（冰）古尼', '中信出版集团'], ['六日战争', '未知', '[以] 迈克尔·B. 奥伦', '后浪丨九州出版社', '2020-11'], ['恶人', '未知', '[美] 詹姆斯·道斯', '上海三联书店', '2020-11'], ['照护', '未知', '[美] 凯博文', '中信出版社', '2020-11'], ['在中国大地上', '未知', '[美] 保罗·索鲁', '后浪丨九州出版社', '2020-12'], ['隋唐世界帝国的形成', '未知', '[日] 谷川道雄', '后浪×楚尘文化丨九州出版社', '2020-11'], ['优素福·卡什：镜头内外', '9.8', '[美] 戴维·特拉维斯', '后浪丨湖南美术出版社', '2020-11']]
# 18
# 40
# 37
# 36
# 40
# 39
# 41
# 35
# 40
# 34
# 33
# 44
# 49
# 46
# 47
# 45
# 33
# 35
# 36
# 52
# 32
# 37
# 40
# 41
# 35
# 35
# 55
# 30
# 35
# 32
# 46
# 28
# 70
# 30
# 26
# 39
# 32
# 28
# 37
# 44
# 47
